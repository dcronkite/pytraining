# %% [markdown]
# # Natural Language Processing
#
# 1. What is NLP?
#     * A variety of areas in which linguistics meets mathematics and/or computer science
#     * Example of interacting with a speech bot:
#         - Speech-to-text: creating letters/words/sentences from continuous sounds
#         - Natural language understanding: mapping the sentences to some semantic representation
#         - Dialog systems: determining appropriate response given semantic representation
#         - Information extraction/retrieval: collecting any data needed to make the response
#         - Natural language generation: generating words and sentences in a target language
#         - Text-to-speech: creating continuous sounds from letters/words/sentences
#     * Locally, we tend to do *Information Extraction*, which is essentially converting free-text to structured data
# 2. Terminology
#     * Corpus (pl. corpora): dataset, consisting of documents/notes
#     * Document/note: the smallest self-contained unit of analysis (e.g., a comment, post, blog, newspaper article, clinical note, etc.)
#     * Token: smallest word or punctuation (_don't_ can have two tokens: _do_ and _n't_)
#     * Lemma/stem: canonical form of word (map _hurt_ and _hurts_ to the same word)
# 2. Sentiment analysis example
#     * Based on terms, can we learn about people's attitudes, emotions, or perceptions
# 3. Spam/ham classification
#     * Classic example using ML in NLP
# 4. nltk
#     * A popular library, but also very useful to _learn_ basic NLP
#     * http://www.nltk.org/book/
#     * POS-tagging
#     * Syntactic analysis
#     * Spell-correction/edit distance

# %% [markdown]
# ## Sentiment Analysis
#
# Sentiment analysis is concerned about learning the subjective information about actors in a particular setting. This is often concerned with detecting 'positive' vs 'neutral' vs 'negative' comments, though we will consider an example of the use of male and female terms in a particular document.

# %%
import nltk
# sentence splitting/tokenization, etc require models, and these must be downloaded separately
nltk.download()  # or download from http://www.nltk.org/nltk_data/
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
from enum import Enum

class Category(Enum):
    C1 = 0
    C2 = 1
    BOTH = 2
    UNKNOWN = 3

# %%
MALE_TERMS = {
    'man', 'men', 'mans', 'mens', 'guy', 'guys', 'him', 'he', 'hes', 'his',
    'boy', 'boys', 'boyfriend', 'boyfriends', 'brother', 'brothers', 'dad', 'dads',
    'father', 'fathers', 'spokesman', 'spokesmen', 'spokesmans', 'gentleman',
    'gentlemans', 'gentlemen', 'gentlemens', 'groom', 'grooms', 'son', 'sons', 
    'grandson', 'grandsons', 'grandpa', 'grandpas', 'grandfather', 'grandfathers',
    'fiance', 'fiances', 'male', 'males', 'king', 'kings', 'mr', 'himself',
    'sir', 'sirs', 'nephew', 'nephews', 'uncle', 'uncles', 'husband', 'husbands',
    'waiter', 'waiters', 'widower', 'widowers', 'prince', 'princes', 'priest',
    'priests', 'chairman', 'chairmen', 'chairmans', 'chairmens'
}
FEMALE_TERMS = {
    'woman', 'women', 'womans', 'womens', 'gal', 'gals', 'her', 'she', 'shes', 'hers',
    'girl', 'girls', 'girlfriend', 'girlfriends', 'sister', 'sisters', 'mom', 'moms',
    'mother', 'mothers', 'spokeswoman', 'spokeswomen', 'spokeswomans', 'lady', 'ladys'
    'ladies', 'bride', 'brides', 'daughter', 'daughters', 'miss',
    'granddaughter', 'granddaughters', 'grandma', 'grandmas', 'grandmother', 'grandmothers',
    'fiancee', 'fiancees', 'female', 'females', 'queen', 'queens', 'mrs', 'herself',
    'niece', 'nieces', 'aunt', 'aunt', 'wife', 'wifes', 'wives',
    'waitress', 'waitresses', 'widow', 'widows', 'princess', 'princesses', 'priestess',
    'priestesses', 'chairwoman', 'chairwomans', 'chairwomen', 'chairwomens'
}

# %%
# remove punctuation
from string import punctuation
TABLE = str.maketrans('', '', punctuation + '’—“')

# %%
def get_sentence(text):
    for sent in nltk.sent_tokenize(text):
        yield {word.lower().translate(TABLE) for word in nltk.word_tokenize(sent) if word.translate(TABLE).strip()}
            
def parse_category(texts, cat1, cat2, label1, label2):
    all_sents = Counter()
    all_words = Counter()
    terms = defaultdict(lambda: Counter())
    for title, text in texts:
        sents, words = count_category(get_sentence(text), cat1, cat2, terms)
        all_sents += sents
        all_words += words
        total = sum(words.values())
        for cat, count in words.items():
            percent = count * 100 / total
            num_sents = sents[cat]
            if cat == Category.C1:
                label = label1
            elif cat == Category.C2:
                label = label2
            else:
                label = cat
            print(title)
            print(f'{percent:0.2f}% {label} ({num_sents} sentences)')
    for cat in terms:
        if cat == Category.C1:
            label = label1
        elif cat == Category.C2:
            label = label2
        else:
            label = cat
        print(f'{label}\n\t', end='')
        for term in terms[cat].most_common(20):
            print(f'{term[0]}', end=',')
        print()

# %%
from collections import Counter, defaultdict

def count_category(sentences, cat1, cat2, terms):
    sents = Counter()
    words = Counter()
    for sent in sentences:
        cat = judge_category(sent, cat1, cat2)
        sents[cat] += 1  # number of sentences with this category
        words[cat] += len(sent)  # number of words in this category
        terms[cat].update({s for s in sent if s not in stopwords})  # word counts in this category
    return words, sents

# %%
def judge_category(words, cat1, cat2):
    count1 = len(cat1 & words)
    count2 = len(cat2 & words)
    if count1 > 0 and count2 > 0:
        return Category.BOTH
    elif count1 > 0:
        return Category.C1
    elif count2 > 0:
        return Category.C2
    else:
        return Category.UNKNOWN

# %%
texts = []
with open(r'data\grandmothers-love.txt') as fh:
    texts.append(('grandmothers-love', fh.read()))

parse_category(texts, MALE_TERMS, FEMALE_TERMS, 'male', 'female')
# Out:
# grandmothers-love
# 6.67% male (98 sentences)
# grandmothers-love
# 35.56% female (468 sentences)
# grandmothers-love
# 55.56% Category.UNKNOWN (457 sentences)
# grandmothers-love
# 2.22% Category.BOTH (7 sentences)
# male
# 	community,history,beason,shaped,views,foundation,face,socialjustice,today,tyrone,times,issues,serves,seattle,columnist,new,parents,early,card,attended,
# female
# 	knew,woman,teacher,used,black,way,back,name,grandmother,white,mama,big,might,day,first,said,two,pride,told,house,
# Category.UNKNOWN
# 	people,justice,history,eyes,turn,teacher,mean,harm,life,better,living,born,country,keep,toward,see,opportunity,time,write,like,
# Category.BOTH
# 	big,dad,mama,mother,

# %%
docs = iter((fileid, nltk.corpus.reuters.raw(fileid)) for fileid in nltk.corpus.reuters.fileids())
parse_category(docs, MALE_TERMS, FEMALE_TERMS, 'male', 'female')
# Out:
# test/14826
# 83.87% Category.UNKNOWN (565 sentences)
# test/14826
# 16.13% male (99 sentences)
# test/14828
# 100.00% Category.UNKNOWN (92 sentences)
# test/14829
# 100.00% Category.UNKNOWN (150 sentences)
# test/14832
# 100.00% Category.UNKNOWN (132 sentences)
# test/14833
# 100.00% Category.UNKNOWN (144 sentences)
# test/14839
# 100.00% Category.UNKNOWN (179 sentences)
# test/14840
# 26.32% male (131 sentences)
# test/14840
# 73.68% Category.UNKNOWN (230 sentences)
# test/14841
# 100.00% Category.UNKNOWN (48 sentences)
# test/14842
# 100.00% Category.UNKNOWN (106 sentences)
# test/14843
# 82.86% Category.UNKNOWN (504 sentences)
# test/14843
# 17.14% male (124 sentences)
# test/14844
# 60.00% Category.UNKNOWN (56 sentences)
# test/14844
# 40.00% male (37 sentences)
# test/14849
# 33.33% male (79 sentences)
# test/14849
# 66.67% Category.UNKNOWN (141 sentences)
# test/14852
# 100.00% Category.UNKNOWN (236 sentences)
# test/14854
# 100.00% Category.UNKNOWN (86 sentences)
# test/14858
# 86.36% Category.UNKNOWN (349 sentences)
# test/14858
# 13.64% male (68 sentences)
# test/14859
# 100.00% Category.UNKNOWN (96 sentences)
# test/14860
# 100.00% Category.UNKNOWN (65 sentences)
# test/14861
# 100.00% Category.UNKNOWN (83 sentences)
# test/14862
# 72.22% Category.UNKNOWN (289 sentences)
# test/14862
# 27.78% male (101 sentences)
# test/14863
# 100.00% Category.UNKNOWN (236 sentences)
# test/14865
# 100.00% Category.UNKNOWN (89 sentences)
# test/14867
# 100.00% Category.UNKNOWN (96 sentences)
# test/14872
# 100.00% Category.UNKNOWN (148 sentences)
# test/14873
# 100.00% Category.UNKNOWN (175 sentences)
# test/14875
# 100.00% Category.UNKNOWN (85 sentences)
# test/14876
# 100.00% Category.UNKNOWN (47 sentences)
# test/14877
# 50.00% Category.UNKNOWN (43 sentences)
# test/14877
# 50.00% male (53 sentences)
# test/14881
# 60.00% Category.UNKNOWN (111 sentences)
# test/14881
# 40.00% male (59 sentences)
# test/14882
# 75.00% Category.UNKNOWN (53 sentences)
# test/14882
# 25.00% male (33 sentences)
# test/14885
# 100.00% Category.UNKNOWN (92 sentences)
# test/14886
# 100.00% Category.UNKNOWN (23 sentences)
# test/14888
# 66.67% Category.UNKNOWN (151 sentences)
# test/14888
# 33.33% male (70 sentences)
# test/14890
# 93.10% Category.UNKNOWN (637 sentences)
# test/14890
# 6.90% male (49 sentences)
# test/14891
# 96.55% Category.UNKNOWN (652 sentences)
# test/14891
# 3.45% male (20 sentences)
# test/14892
# 100.00% Category.UNKNOWN (224 sentences)
# test/14899
# 100.00% Category.UNKNOWN (11 sentences)
# test/14900
# 33.33% male (62 sentences)
# test/14900
# 66.67% Category.UNKNOWN (99 sentences)
# test/14903
# 33.33% male (43 sentences)
# test/14903
# 66.67% Category.UNKNOWN (30 sentences)
# test/14904
# 40.00% male (84 sentences)
# test/14904
# 60.00% Category.UNKNOWN (113 sentences)
# test/14907
# 75.00% Category.UNKNOWN (50 sentences)
# test/14907
# 25.00% male (35 sentences)
# test/14909
# 85.71% Category.UNKNOWN (128 sentences)
# test/14909
# 14.29% male (23 sentences)
# test/14911
# 57.14% Category.UNKNOWN (88 sentences)
# test/14911
# 42.86% male (119 sentences)
# test/14912
# 60.00% Category.UNKNOWN (111 sentences)
# test/14912
# 40.00% male (59 sentences)
# test/14913
# 100.00% Category.UNKNOWN (76 sentences)
# test/14918
# 100.00% Category.UNKNOWN (31 sentences)
# test/14919
# 100.00% Category.UNKNOWN (64 sentences)
# test/14921
# 77.42% Category.UNKNOWN (515 sentences)
# test/14921
# 22.58% male (183 sentences)
# test/14922
# 62.50% male (116 sentences)
# test/14922
# 37.50% Category.UNKNOWN (52 sentences)
# test/14923
# 100.00% Category.UNKNOWN (98 sentences)
# test/14926
# 100.00% Category.UNKNOWN (86 sentences)
# test/14928
# 16.67% male (26 sentences)
# test/14928
# 83.33% Category.UNKNOWN (151 sentences)
# test/14930
# 100.00% Category.UNKNOWN (83 sentences)
# test/14931
# 52.63% Category.UNKNOWN (236 sentences)
# test/14931
# 47.37% male (175 sentences)
# test/14932
# 100.00% Category.UNKNOWN (74 sentences)
# test/14933
# 100.00% Category.UNKNOWN (125 sentences)
# test/14934
# 100.00% Category.UNKNOWN (19 sentences)
# test/14941
# 62.50% male (100 sentences)
# test/14941
# 37.50% Category.UNKNOWN (47 sentences)
# test/14943
# 100.00% Category.UNKNOWN (13 sentences)
# test/14949
# 100.00% Category.UNKNOWN (120 sentences)
# test/14951
# 75.00% Category.UNKNOWN (71 sentences)
# test/14951
# 25.00% male (19 sentences)
# test/14954
# 100.00% Category.UNKNOWN (28 sentences)
# test/14957
# 100.00% Category.UNKNOWN (112 sentences)
# test/14958
# 100.00% Category.UNKNOWN (9 sentences)
# test/14959
# 42.86% male (97 sentences)
# test/14959
# 14.29% female (31 sentences)
# test/14959
# 42.86% Category.UNKNOWN (68 sentences)
# test/14960
# 100.00% Category.UNKNOWN (36 sentences)
# test/14962
# 100.00% Category.UNKNOWN (18 sentences)
# test/14963
# 100.00% Category.UNKNOWN (30 sentences)
# test/14964
# 100.00% Category.UNKNOWN (80 sentences)
# test/14965
# 100.00% Category.UNKNOWN (11 sentences)
# test/14967
# 100.00% Category.UNKNOWN (46 sentences)
# test/14968
# 100.00% Category.UNKNOWN (19 sentences)
# test/14969
# 100.00% Category.UNKNOWN (42 sentences)
# test/14970
# 100.00% Category.UNKNOWN (32 sentences)
# test/14971
# 100.00% Category.UNKNOWN (28 sentences)
# test/14974
# 100.00% Category.UNKNOWN (29 sentences)
# test/14975
# 71.43% Category.UNKNOWN (110 sentences)
# test/14975
# 28.57% male (43 sentences)
# test/14978
# 85.71% Category.UNKNOWN (61 sentences)
# test/14978
# 14.29% male (19 sentences)
# test/14981
# 100.00% Category.UNKNOWN (26 sentences)
# test/14982
# 50.00% male (186 sentences)
# test/14982
# 50.00% Category.UNKNOWN (204 sentences)
# test/14983
# 100.00% Category.UNKNOWN (46 sentences)
# test/14984
# 100.00% Category.UNKNOWN (187 sentences)
# test/14985
# 100.00% Category.UNKNOWN (20 sentences)
# test/14986
# 100.00% Category.UNKNOWN (28 sentences)
# test/14987
# 62.50% Category.UNKNOWN (220 sentences)
# test/14987
# 37.50% male (105 sentences)
# test/14988
# 100.00% Category.UNKNOWN (147 sentences)
# test/14993
# 75.00% Category.UNKNOWN (118 sentences)
# test/14993
# 25.00% male (51 sentences)
# test/14995
# 100.00% Category.UNKNOWN (19 sentences)
# test/14998
# 100.00% Category.UNKNOWN (40 sentences)
# test/15000
# 100.00% Category.UNKNOWN (39 sentences)
# test/15001
# 100.00% Category.UNKNOWN (22 sentences)
# test/15002
# 100.00% Category.UNKNOWN (21 sentences)
# test/15004
# 100.00% Category.UNKNOWN (38 sentences)
# test/15005
# 100.00% Category.UNKNOWN (76 sentences)
# test/15006
# 100.00% male (20 sentences)
# test/15011
# 100.00% Category.UNKNOWN (28 sentences)
# test/15012
# 100.00% Category.UNKNOWN (19 sentences)
# test/15013
# 42.86% male (90 sentences)
# test/15013
# 57.14% Category.UNKNOWN (89 sentences)
# test/15016
# 100.00% Category.UNKNOWN (12 sentences)
# test/15017
# 100.00% Category.UNKNOWN (51 sentences)
# test/15020
# 90.91% Category.UNKNOWN (173 sentences)
# test/15020
# 9.09% male (14 sentences)
# test/15023
# 100.00% Category.UNKNOWN (19 sentences)
# test/15024
# 100.00% Category.UNKNOWN (60 sentences)
# test/15026
# 100.00% Category.UNKNOWN (61 sentences)
# test/15027
# 100.00% Category.UNKNOWN (16 sentences)
# test/15028
# 100.00% Category.UNKNOWN (49 sentences)
# test/15029
# 100.00% Category.UNKNOWN (55 sentences)
# test/15031
# 100.00% Category.UNKNOWN (92 sentences)
# test/15032
# 100.00% Category.UNKNOWN (25 sentences)
# test/15033
# 100.00% Category.UNKNOWN (144 sentences)
# test/15037
# 100.00% Category.UNKNOWN (30 sentences)
# test/15038
# 100.00% Category.UNKNOWN (51 sentences)
# test/15043
# 100.00% Category.UNKNOWN (551 sentences)
# test/15045
# 55.56% Category.UNKNOWN (69 sentences)
# test/15045
# 33.33% male (53 sentences)
# test/15045
# 11.11% female (16 sentences)
# test/15046
# 100.00% Category.UNKNOWN (2 sentences)
# test/15048
# 85.71% Category.UNKNOWN (134 sentences)
# test/15048
# 14.29% male (28 sentences)
# test/15049
# 100.00% Category.UNKNOWN (86 sentences)
# test/15052
# 100.00% Category.UNKNOWN (57 sentences)
# test/15053
# 100.00% Category.UNKNOWN (21 sentences)
# test/15055
# 100.00% Category.UNKNOWN (133 sentences)
# test/15056
# 100.00% Category.UNKNOWN (50 sentences)
# test/15060
# 100.00% Category.UNKNOWN (79 sentences)
# test/15061
# 100.00% Category.UNKNOWN (49 sentences)
# test/15062
# 100.00% Category.UNKNOWN (24 sentences)
# test/15063
# 88.57% Category.UNKNOWN (676 sentences)
# test/15063
# 11.43% male (103 sentences)
# test/15065
# 100.00% Category.UNKNOWN (104 sentences)
# test/15067
# 100.00% Category.UNKNOWN (34 sentences)
# test/15069
# 100.00% Category.UNKNOWN (9 sentences)
# test/15070
# 100.00% Category.UNKNOWN (9 sentences)
# test/15074
# 100.00% Category.UNKNOWN (10 sentences)
# test/15077
# 100.00% Category.UNKNOWN (18 sentences)
# test/15078
# 100.00% Category.UNKNOWN (17 sentences)
# test/15079
# 100.00% Category.UNKNOWN (23 sentences)
# test/15082
# 100.00% Category.UNKNOWN (19 sentences)
# test/15090
# 100.00% Category.UNKNOWN (42 sentences)
# test/15091
# 40.00% male (103 sentences)
# test/15091
# 60.00% Category.UNKNOWN (146 sentences)
# test/15092
# 100.00% Category.UNKNOWN (6 sentences)
# test/15093
# 100.00% Category.UNKNOWN (95 sentences)
# test/15094
# 100.00% Category.UNKNOWN (64 sentences)
# test/15095
# 91.67% Category.UNKNOWN (229 sentences)
# test/15095
# 8.33% male (25 sentences)
# test/15096
# 50.00% male (22 sentences)
# test/15096
# 50.00% Category.UNKNOWN (24 sentences)
# test/15097
# 100.00% Category.UNKNOWN (116 sentences)
# test/15103
# 93.33% Category.UNKNOWN (329 sentences)
# test/15103
# 6.67% female (33 sentences)
# test/15104
# 100.00% Category.UNKNOWN (28 sentences)
# test/15106
# 27.27% male (73 sentences)
# test/15106
# 72.73% Category.UNKNOWN (157 sentences)
# test/15107
# 75.00% Category.UNKNOWN (77 sentences)
# test/15107
# 25.00% male (25 sentences)
# test/15109
# 100.00% Category.UNKNOWN (20 sentences)
# test/15110
# 45.45% male (110 sentences)
# test/15110
# 54.55% Category.UNKNOWN (90 sentences)
# test/15111
# 100.00% Category.UNKNOWN (39 sentences)
# test/15112
# 71.43% Category.UNKNOWN (99 sentences)
# test/15112
# 28.57% male (47 sentences)
# test/15118
# 100.00% Category.UNKNOWN (17 sentences)
# test/15119
# 100.00% Category.UNKNOWN (33 sentences)
# test/15120
# 100.00% Category.UNKNOWN (30 sentences)
# test/15121
# 100.00% Category.UNKNOWN (189 sentences)
# test/15122
# 100.00% Category.UNKNOWN (120 sentences)
# test/15124
# 100.00% Category.UNKNOWN (9 sentences)
# test/15126
# 100.00% Category.UNKNOWN (27 sentences)
# test/15128
# 100.00% Category.UNKNOWN (95 sentences)
# test/15129
# 100.00% Category.UNKNOWN (22 sentences)
# test/15130
# 100.00% Category.UNKNOWN (40 sentences)
# test/15132
# 100.00% Category.UNKNOWN (82 sentences)
# test/15136
# 100.00% Category.UNKNOWN (45 sentences)
# test/15138
# 100.00% Category.UNKNOWN (24 sentences)
# test/15141
# 100.00% Category.UNKNOWN (39 sentences)
# test/15144
# 100.00% Category.UNKNOWN (20 sentences)
# test/15145
# 100.00% Category.UNKNOWN (59 sentences)
# test/15146
# 100.00% Category.UNKNOWN (81 sentences)
# test/15149
# 66.67% Category.UNKNOWN (367 sentences)
# test/15149
# 23.33% male (117 sentences)
# test/15149
# 10.00% female (40 sentences)
# test/15152
# 100.00% Category.UNKNOWN (20 sentences)
# test/15153
# 100.00% Category.UNKNOWN (18 sentences)
# test/15154
# 56.25% Category.UNKNOWN (218 sentences)
# test/15154
# 43.75% male (151 sentences)
# test/15156
# 100.00% Category.UNKNOWN (127 sentences)
# test/15157
# 100.00% Category.UNKNOWN (18 sentences)
# test/15161
# 66.67% Category.UNKNOWN (59 sentences)
# test/15161
# 33.33% male (15 sentences)
# test/15162
# 100.00% Category.UNKNOWN (81 sentences)
# test/15171
# 60.00% male (72 sentences)
# test/15171
# 40.00% Category.UNKNOWN (26 sentences)
# test/15172
# 100.00% Category.UNKNOWN (12 sentences)
# test/15175
# 100.00% Category.UNKNOWN (24 sentences)
# test/15179
# 100.00% male (116 sentences)
# test/15180
# 100.00% Category.UNKNOWN (30 sentences)
# test/15185
# 100.00% Category.UNKNOWN (9 sentences)
# test/15188
# 100.00% Category.UNKNOWN (28 sentences)
# test/15189
# 100.00% Category.UNKNOWN (101 sentences)
# test/15190
# 100.00% Category.UNKNOWN (61 sentences)
# test/15193
# 100.00% Category.UNKNOWN (40 sentences)
# test/15194
# 77.27% Category.UNKNOWN (380 sentences)
# test/15194
# 22.73% male (136 sentences)
# test/15197
# 100.00% Category.UNKNOWN (21 sentences)
# test/15198
# 66.67% Category.UNKNOWN (57 sentences)
# test/15198
# 33.33% male (28 sentences)
# test/15200
# 100.00% Category.UNKNOWN (183 sentences)
# test/15204
# 100.00% Category.UNKNOWN (35 sentences)
# test/15205
# 100.00% Category.UNKNOWN (43 sentences)
# test/15206
# 72.73% Category.UNKNOWN (159 sentences)
# test/15206
# 27.27% male (63 sentences)
# test/15207
# 100.00% Category.UNKNOWN (23 sentences)
# test/15208
# 100.00% Category.UNKNOWN (19 sentences)
# test/15210
# 100.00% Category.UNKNOWN (76 sentences)
# test/15211
# 100.00% Category.UNKNOWN (53 sentences)
# test/15212
# 83.33% male (156 sentences)
# test/15212
# 16.67% Category.UNKNOWN (20 sentences)
# test/15213
# 70.00% Category.UNKNOWN (263 sentences)
# test/15213
# 30.00% male (136 sentences)
# test/15217
# 75.00% Category.UNKNOWN (60 sentences)
# test/15217
# 25.00% male (29 sentences)
# test/15219
# 100.00% Category.UNKNOWN (158 sentences)
# test/15220
# 66.67% Category.UNKNOWN (66 sentences)
# test/15220
# 33.33% male (30 sentences)
# test/15221
# 100.00% Category.UNKNOWN (34 sentences)
# test/15222
# 100.00% Category.UNKNOWN (13 sentences)
# test/15223
# 50.00% Category.UNKNOWN (54 sentences)
# test/15223
# 50.00% male (43 sentences)
# test/15226
# 85.71% Category.UNKNOWN (142 sentences)
# test/15226
# 14.29% male (33 sentences)
# test/15227
# 100.00% Category.UNKNOWN (224 sentences)
# test/15230
# 100.00% Category.UNKNOWN (196 sentences)
# test/15233
# 100.00% Category.UNKNOWN (48 sentences)
# test/15234
# 100.00% Category.UNKNOWN (64 sentences)
# test/15237
# 100.00% Category.UNKNOWN (92 sentences)
# test/15238
# 100.00% Category.UNKNOWN (258 sentences)
# test/15239
# 20.83% male (101 sentences)
# test/15239
# 79.17% Category.UNKNOWN (286 sentences)
# test/15240
# 25.00% male (38 sentences)
# test/15240
# 62.50% Category.UNKNOWN (99 sentences)
# test/15240
# 12.50% Category.BOTH (28 sentences)
# test/15242
# 100.00% Category.UNKNOWN (10 sentences)
# test/15243
# 100.00% Category.UNKNOWN (10 sentences)
# test/15244
# 100.00% Category.UNKNOWN (72 sentences)
# test/15246
# 53.33% male (174 sentences)
# test/15246
# 46.67% Category.UNKNOWN (134 sentences)
# test/15247
# 100.00% Category.UNKNOWN (30 sentences)
# test/15250
# 100.00% Category.UNKNOWN (98 sentences)
# test/15253
# 88.89% Category.UNKNOWN (152 sentences)
# test/15253
# 11.11% male (19 sentences)
# test/15254
# 77.78% Category.UNKNOWN (394 sentences)
# test/15254
# 22.22% male (73 sentences)
# test/15255
# 73.33% Category.UNKNOWN (233 sentences)
# test/15255
# 26.67% female (51 sentences)
# test/15258
# 100.00% Category.UNKNOWN (17 sentences)
# test/15259
# 100.00% Category.UNKNOWN (28 sentences)
# test/15262
# 100.00% Category.UNKNOWN (10 sentences)
# test/15263
# 83.33% Category.UNKNOWN (245 sentences)
# test/15263
# 16.67% male (34 sentences)
# test/15264
# 69.23% Category.UNKNOWN (190 sentences)
# test/15264
# 30.77% male (64 sentences)
# test/15265
# 100.00% Category.UNKNOWN (15 sentences)
# test/15270
# 100.00% Category.UNKNOWN (152 sentences)
# test/15271
# 100.00% Category.UNKNOWN (85 sentences)
# test/15273
# 100.00% Category.UNKNOWN (49 sentences)
# test/15274
# 100.00% Category.UNKNOWN (90 sentences)
# test/15276
# 100.00% Category.UNKNOWN (91 sentences)
# test/15278
# 100.00% Category.UNKNOWN (28 sentences)
# test/15280
# 100.00% Category.UNKNOWN (56 sentences)
# test/15281
# 80.00% Category.UNKNOWN (77 sentences)
# test/15281
# 20.00% male (32 sentences)
# test/15283
# 100.00% Category.UNKNOWN (18 sentences)
# test/15287
# 100.00% Category.UNKNOWN (115 sentences)
# test/15290
# 100.00% Category.UNKNOWN (109 sentences)
# test/15292
# 50.00% male (47 sentences)
# test/15292
# 50.00% Category.UNKNOWN (48 sentences)
# test/15294
# 100.00% Category.UNKNOWN (70 sentences)
# test/15295
# 100.00% Category.UNKNOWN (19 sentences)
# test/15296
# 100.00% Category.UNKNOWN (71 sentences)
# test/15299
# 100.00% Category.UNKNOWN (21 sentences)
# test/15300
# 100.00% Category.UNKNOWN (20 sentences)
# test/15302
# 100.00% Category.UNKNOWN (15 sentences)
# test/15303
# 100.00% Category.UNKNOWN (108 sentences)
# test/15306
# 100.00% Category.UNKNOWN (106 sentences)
# test/15307
# 100.00% Category.UNKNOWN (43 sentences)
# test/15308
# 90.00% Category.UNKNOWN (173 sentences)
# test/15308
# 10.00% female (13 sentences)
# test/15309
# 100.00% Category.UNKNOWN (56 sentences)
# test/15310
# 71.43% Category.UNKNOWN (130 sentences)
# test/15310
# 28.57% male (55 sentences)
# test/15311
# 100.00% Category.UNKNOWN (35 sentences)
# test/15312
# 100.00% Category.UNKNOWN (101 sentences)
# test/15313
# 85.71% Category.UNKNOWN (160 sentences)
# test/15313
# 14.29% female (22 sentences)
# test/15314
# 62.50% Category.UNKNOWN (106 sentences)
# test/15314
# 37.50% male (48 sentences)
# test/15315
# 100.00% Category.UNKNOWN (33 sentences)
# test/15321
# 100.00% Category.UNKNOWN (25 sentences)
# test/15322
# 83.33% Category.UNKNOWN (92 sentences)
# test/15322
# 16.67% male (38 sentences)
# test/15324
# 100.00% Category.UNKNOWN (99 sentences)
# test/15325
# 100.00% Category.UNKNOWN (263 sentences)
# test/15326
# 100.00% Category.UNKNOWN (55 sentences)
# test/15327
# 100.00% Category.UNKNOWN (31 sentences)
# test/15329
# 66.67% Category.UNKNOWN (49 sentences)
# test/15329
# 33.33% male (30 sentences)
# test/15335
# 100.00% Category.UNKNOWN (147 sentences)
# test/15336
# 100.00% Category.UNKNOWN (18 sentences)
# test/15337
# 100.00% Category.UNKNOWN (49 sentences)
# test/15339
# 100.00% Category.UNKNOWN (12 sentences)
# test/15341
# 100.00% Category.UNKNOWN (77 sentences)
# test/15344
# 100.00% Category.UNKNOWN (94 sentences)
# test/15345
# 100.00% Category.UNKNOWN (194 sentences)
# test/15348
# 100.00% Category.UNKNOWN (34 sentences)
# test/15349
# 100.00% Category.UNKNOWN (253 sentences)
# test/15351
# 100.00% Category.UNKNOWN (149 sentences)
# test/15352
# 76.67% Category.UNKNOWN (555 sentences)
# test/15352
# 23.33% male (197 sentences)
# test/15354
# 100.00% Category.UNKNOWN (32 sentences)
# test/15356
# 100.00% Category.UNKNOWN (31 sentences)
# test/15357
# 71.43% Category.UNKNOWN (115 sentences)
# test/15357
# 28.57% male (35 sentences)
# test/15359
# 100.00% Category.UNKNOWN (33 sentences)
# test/15363
# 92.86% Category.UNKNOWN (220 sentences)
# test/15363
# 7.14% male (15 sentences)
# test/15364
# 88.46% Category.UNKNOWN (466 sentences)
# test/15364
# 11.54% male (76 sentences)
# test/15365
# 100.00% Category.UNKNOWN (85 sentences)
# test/15366
# 100.00% Category.UNKNOWN (98 sentences)
# test/15367
# 90.00% Category.UNKNOWN (154 sentences)
# test/15367
# 10.00% male (15 sentences)
# test/15368
# 60.00% Category.UNKNOWN (54 sentences)
# test/15368
# 40.00% male (32 sentences)
# test/15372
# 88.89% Category.UNKNOWN (551 sentences)
# test/15372
# 11.11% male (45 sentences)
# test/15375
# 100.00% Category.UNKNOWN (253 sentences)
# test/15378
# 100.00% Category.UNKNOWN (68 sentences)
# test/15379
# 100.00% Category.UNKNOWN (12 sentences)
# test/15380
# 100.00% Category.UNKNOWN (96 sentences)
# test/15383
# 100.00% Category.UNKNOWN (20 sentences)
# test/15384
# 83.33% Category.UNKNOWN (227 sentences)
# test/15384
# 16.67% male (48 sentences)
# test/15386
# 100.00% Category.UNKNOWN (92 sentences)
# test/15387
# 100.00% Category.UNKNOWN (70 sentences)
# test/15388
# 100.00% Category.UNKNOWN (79 sentences)
# test/15389
# 100.00% Category.UNKNOWN (176 sentences)
# test/15391
# 100.00% Category.UNKNOWN (37 sentences)
# test/15394
# 100.00% Category.UNKNOWN (142 sentences)
# test/15396
# 100.00% Category.UNKNOWN (93 sentences)
# test/15397
# 100.00% Category.UNKNOWN (65 sentences)
# test/15400
# 57.14% Category.UNKNOWN (110 sentences)
# test/15400
# 42.86% male (42 sentences)
# test/15404
# 100.00% Category.UNKNOWN (92 sentences)
# test/15406
# 100.00% Category.UNKNOWN (56 sentences)
# test/15409
# 100.00% Category.UNKNOWN (95 sentences)
# test/15410
# 100.00% Category.UNKNOWN (116 sentences)
# test/15411
# 100.00% Category.UNKNOWN (27 sentences)
# test/15413
# 86.67% Category.UNKNOWN (223 sentences)
# test/15413
# 13.33% male (54 sentences)
# test/15415
# 100.00% Category.UNKNOWN (64 sentences)
# test/15416
# 85.71% Category.UNKNOWN (114 sentences)
# test/15416
# 14.29% male (9 sentences)
# test/15417
# 100.00% Category.UNKNOWN (289 sentences)
# test/15420
# 100.00% Category.UNKNOWN (33 sentences)
# test/15421
# 100.00% Category.UNKNOWN (228 sentences)
# test/15424
# 100.00% Category.UNKNOWN (149 sentences)
# test/15425
# 100.00% Category.UNKNOWN (80 sentences)
# test/15427
# 100.00% Category.UNKNOWN (92 sentences)
# test/15428
# 100.00% Category.UNKNOWN (11 sentences)
# test/15429
# 100.00% Category.UNKNOWN (61 sentences)
# test/15430
# 100.00% Category.UNKNOWN (69 sentences)
# test/15431
# 100.00% Category.UNKNOWN (88 sentences)
# test/15432
# 66.67% Category.UNKNOWN (62 sentences)
# test/15432
# 33.33% male (19 sentences)
# test/15436
# 100.00% Category.UNKNOWN (57 sentences)
# test/15438
# 100.00% Category.UNKNOWN (214 sentences)
# test/15441
# 100.00% Category.UNKNOWN (2 sentences)
# test/15442
# 78.79% Category.UNKNOWN (566 sentences)
# test/15442
# 6.06% female (27 sentences)
# test/15442
# 15.15% male (98 sentences)
# test/15444
# 100.00% Category.UNKNOWN (335 sentences)
# test/15446
# 100.00% Category.UNKNOWN (50 sentences)
# test/15447
# 100.00% Category.UNKNOWN (179 sentences)
# test/15448
# 100.00% Category.UNKNOWN (59 sentences)
# test/15449
# 100.00% Category.UNKNOWN (77 sentences)
# test/15450
# 100.00% Category.UNKNOWN (349 sentences)
# test/15451
# 100.00% Category.UNKNOWN (312 sentences)
# test/15452
# 100.00% Category.UNKNOWN (253 sentences)
# test/15453
# 50.00% Category.UNKNOWN (139 sentences)
# test/15453
# 50.00% male (142 sentences)
# test/15454
# 100.00% Category.UNKNOWN (348 sentences)
# test/15455
# 57.14% Category.UNKNOWN (110 sentences)
# test/15455
# 42.86% male (42 sentences)
# test/15457
# 100.00% Category.UNKNOWN (18 sentences)
# test/15459
# 100.00% male (46 sentences)
# test/15460
# 73.91% Category.UNKNOWN (382 sentences)
# test/15460
# 8.70% female (27 sentences)
# test/15460
# 17.39% male (96 sentences)
# test/15462
# 33.33% Category.UNKNOWN (21 sentences)
# test/15462
# 66.67% male (49 sentences)
# test/15464
# 100.00% Category.UNKNOWN (43 sentences)
# test/15467
# 100.00% Category.UNKNOWN (67 sentences)
# test/15468
# 100.00% Category.UNKNOWN (111 sentences)
# test/15471
# 100.00% Category.UNKNOWN (90 sentences)
# test/15472
# 100.00% Category.UNKNOWN (180 sentences)
# test/15476
# 100.00% Category.UNKNOWN (40 sentences)
# test/15477
# 100.00% Category.UNKNOWN (29 sentences)
# test/15478
# 100.00% Category.UNKNOWN (82 sentences)
# test/15479
# 100.00% Category.UNKNOWN (64 sentences)
# test/15481
# 100.00% Category.UNKNOWN (90 sentences)
# test/15482
# 100.00% Category.UNKNOWN (29 sentences)
# test/15483
# 66.67% Category.UNKNOWN (58 sentences)
# test/15483
# 33.33% male (19 sentences)
# test/15484
# 100.00% Category.UNKNOWN (104 sentences)
# test/15485
# 100.00% Category.UNKNOWN (63 sentences)
# test/15487
# 100.00% Category.UNKNOWN (12 sentences)
# test/15489
# 100.00% Category.UNKNOWN (62 sentences)
# test/15494
# 100.00% Category.UNKNOWN (54 sentences)
# test/15495
# 100.00% Category.UNKNOWN (27 sentences)
# test/15496
# 100.00% Category.UNKNOWN (38 sentences)
# test/15500
# 100.00% Category.UNKNOWN (89 sentences)
# test/15501
# 100.00% Category.UNKNOWN (112 sentences)
# test/15503
# 40.00% Category.UNKNOWN (58 sentences)
# test/15503
# 60.00% male (42 sentences)
# test/15504
# 100.00% Category.UNKNOWN (56 sentences)
# test/15510
# 100.00% Category.UNKNOWN (30 sentences)
# test/15511
# 25.00% male (77 sentences)
# test/15511
# 75.00% Category.UNKNOWN (159 sentences)
# test/15515
# 100.00% Category.UNKNOWN (36 sentences)
# test/15520
# 100.00% Category.UNKNOWN (123 sentences)
# test/15521
# 100.00% Category.UNKNOWN (39 sentences)
# test/15522
# 100.00% Category.UNKNOWN (10 sentences)
# test/15523
# 100.00% Category.UNKNOWN (64 sentences)
# test/15527
# 100.00% Category.UNKNOWN (82 sentences)
# test/15528
# 100.00% Category.UNKNOWN (31 sentences)
# test/15531
# 100.00% Category.UNKNOWN (189 sentences)
# test/15532
# 100.00% Category.UNKNOWN (48 sentences)
# test/15535
# 100.00% Category.UNKNOWN (9 sentences)
# test/15536
# 100.00% Category.UNKNOWN (46 sentences)
# test/15539
# 63.64% Category.UNKNOWN (177 sentences)
# test/15539
# 36.36% male (104 sentences)
# test/15540
# 100.00% Category.UNKNOWN (39 sentences)
# test/15542
# 100.00% Category.UNKNOWN (14 sentences)
# test/15543
# 100.00% Category.UNKNOWN (115 sentences)
# test/15544
# 100.00% Category.UNKNOWN (12 sentences)
# test/15545
# 40.00% Category.UNKNOWN (44 sentences)
# test/15545
# 40.00% female (26 sentences)
# test/15545
# 20.00% male (18 sentences)
# test/15547
# 100.00% Category.UNKNOWN (69 sentences)
# test/15548
# 100.00% Category.UNKNOWN (22 sentences)
# test/15549
# 93.33% Category.UNKNOWN (703 sentences)
# test/15549
# 6.67% male (45 sentences)
# test/15550
# 100.00% Category.UNKNOWN (62 sentences)
# test/15551
# 100.00% Category.UNKNOWN (418 sentences)
# test/15552
# 75.00% Category.UNKNOWN (215 sentences)
# test/15552
# 25.00% male (65 sentences)
# test/15553
# 100.00% Category.UNKNOWN (21 sentences)
# test/15556
# 100.00% Category.UNKNOWN (565 sentences)
# test/15558
# 100.00% Category.UNKNOWN (50 sentences)
# test/15559
# 100.00% Category.UNKNOWN (25 sentences)
# test/15560
# 100.00% Category.UNKNOWN (38 sentences)
# test/15561
# 100.00% Category.UNKNOWN (43 sentences)
# test/15562
# 66.67% male (45 sentences)
# test/15562
# 33.33% Category.UNKNOWN (25 sentences)
# test/15563
# 100.00% Category.UNKNOWN (34 sentences)
# test/15565
# 100.00% Category.UNKNOWN (205 sentences)
# test/15566
# 100.00% Category.UNKNOWN (10 sentences)
# test/15567
# 100.00% Category.UNKNOWN (254 sentences)
# test/15568
# 100.00% Category.UNKNOWN (38 sentences)
# test/15569
# 100.00% Category.UNKNOWN (208 sentences)
# test/15570
# 100.00% Category.UNKNOWN (20 sentences)
# test/15571
# 85.71% Category.UNKNOWN (126 sentences)
# test/15571
# 14.29% male (29 sentences)
# test/15572
# 100.00% Category.UNKNOWN (35 sentences)
# test/15573
# 100.00% Category.UNKNOWN (122 sentences)
# test/15574
# 100.00% Category.UNKNOWN (96 sentences)
# test/15575
# 66.67% Category.UNKNOWN (47 sentences)
# test/15575
# 33.33% male (23 sentences)
# test/15578
# 100.00% Category.UNKNOWN (36 sentences)
# test/15579
# 100.00% Category.UNKNOWN (25 sentences)
# test/15580
# 100.00% Category.UNKNOWN (46 sentences)
# test/15581
# 21.43% male (87 sentences)
# test/15581
# 78.57% Category.UNKNOWN (226 sentences)
# test/15582
# 100.00% Category.UNKNOWN (64 sentences)
# test/15583
# 100.00% Category.UNKNOWN (8 sentences)
# test/15584
# 100.00% Category.UNKNOWN (134 sentences)
# test/15585
# 85.71% Category.UNKNOWN (70 sentences)
# test/15585
# 14.29% male (8 sentences)
# test/15590
# 100.00% Category.UNKNOWN (35 sentences)
# test/15591
# 100.00% Category.UNKNOWN (86 sentences)
# test/15593
# 100.00% Category.UNKNOWN (48 sentences)
# test/15594
# 100.00% Category.UNKNOWN (32 sentences)
# test/15595
# 100.00% Category.UNKNOWN (32 sentences)
# test/15596
# 50.00% male (52 sentences)
# test/15596
# 50.00% Category.UNKNOWN (29 sentences)
# test/15597
# 100.00% Category.UNKNOWN (78 sentences)
# test/15598
# 100.00% Category.UNKNOWN (49 sentences)
# test/15600
# 100.00% Category.UNKNOWN (69 sentences)
# test/15601
# 100.00% female (32 sentences)
# test/15602
# 60.00% Category.UNKNOWN (79 sentences)
# test/15602
# 40.00% male (45 sentences)
# test/15603
# 100.00% Category.UNKNOWN (15 sentences)
# test/15605
# 100.00% Category.UNKNOWN (117 sentences)
# test/15607
# 100.00% Category.UNKNOWN (60 sentences)
# test/15610
# 100.00% Category.UNKNOWN (33 sentences)
# test/15613
# 100.00% Category.UNKNOWN (18 sentences)
# test/15615
# 100.00% Category.UNKNOWN (83 sentences)
# test/15616
# 100.00% Category.UNKNOWN (86 sentences)
# test/15617
# 57.89% Category.UNKNOWN (210 sentences)
# test/15617
# 42.11% male (185 sentences)
# test/15618
# 100.00% Category.UNKNOWN (99 sentences)
# test/15620
# 75.00% Category.UNKNOWN (184 sentences)
# test/15620
# 25.00% male (69 sentences)
# test/15621
# 100.00% Category.UNKNOWN (110 sentences)
# test/15623
# 100.00% Category.UNKNOWN (50 sentences)
# test/15624
# 100.00% Category.UNKNOWN (128 sentences)
# test/15625
# 100.00% Category.UNKNOWN (358 sentences)
# test/15626
# 100.00% Category.UNKNOWN (19 sentences)
# test/15629
# 100.00% Category.UNKNOWN (57 sentences)
# test/15632
# 100.00% Category.UNKNOWN (37 sentences)
# test/15634
# 100.00% Category.UNKNOWN (9 sentences)
# test/15636
# 100.00% male (58 sentences)
# test/15637
# 100.00% Category.UNKNOWN (19 sentences)
# test/15639
# 45.16% Category.UNKNOWN (258 sentences)
# test/15639
# 41.94% male (187 sentences)
# test/15639
# 12.90% female (81 sentences)
# test/15640
# 100.00% Category.UNKNOWN (29 sentences)
# test/15641
# 100.00% Category.UNKNOWN (134 sentences)
# test/15642
# 100.00% Category.UNKNOWN (67 sentences)
# test/15643
# 100.00% Category.UNKNOWN (116 sentences)
# test/15646
# 100.00% Category.UNKNOWN (11 sentences)
# test/15648
# 100.00% Category.UNKNOWN (24 sentences)
# test/15649
# 100.00% Category.UNKNOWN (12 sentences)
# test/15651
# 100.00% Category.UNKNOWN (13 sentences)
# test/15653
# 100.00% Category.UNKNOWN (158 sentences)
# test/15655
# 100.00% Category.UNKNOWN (45 sentences)
# test/15656
# 62.50% Category.UNKNOWN (132 sentences)
# test/15656
# 37.50% male (71 sentences)
# test/15664
# 100.00% Category.UNKNOWN (38 sentences)
# test/15666
# 50.00% male (57 sentences)
# test/15666
# 50.00% Category.UNKNOWN (36 sentences)
# test/15667
# 100.00% Category.UNKNOWN (53 sentences)
# test/15668
# 100.00% Category.UNKNOWN (35 sentences)
# test/15669
# 100.00% Category.UNKNOWN (28 sentences)
# test/15672
# 100.00% male (47 sentences)
# test/15674
# 84.62% Category.UNKNOWN (189 sentences)
# test/15674
# 7.69% female (36 sentences)
# test/15674
# 7.69% male (22 sentences)
# test/15675
# 100.00% Category.UNKNOWN (95 sentences)
# test/15676
# 100.00% Category.UNKNOWN (44 sentences)
# test/15677
# 100.00% Category.UNKNOWN (12 sentences)
# test/15679
# 100.00% Category.UNKNOWN (32 sentences)
# test/15680
# 100.00% Category.UNKNOWN (29 sentences)
# test/15682
# 100.00% Category.UNKNOWN (48 sentences)
# test/15686
# 100.00% Category.UNKNOWN (224 sentences)
# test/15688
# 100.00% Category.UNKNOWN (19 sentences)
# test/15689
# 75.00% Category.UNKNOWN (71 sentences)
# test/15689
# 25.00% female (10 sentences)
# test/15691
# 100.00% Category.UNKNOWN (95 sentences)
# test/15692
# 100.00% Category.UNKNOWN (39 sentences)
# test/15694
# 66.67% Category.UNKNOWN (62 sentences)
# test/15694
# 33.33% male (28 sentences)
# test/15695
# 100.00% Category.UNKNOWN (21 sentences)
# test/15696
# 100.00% Category.UNKNOWN (121 sentences)
# test/15698
# 75.00% Category.UNKNOWN (56 sentences)
# test/15698
# 25.00% male (24 sentences)
# test/15702
# 100.00% Category.UNKNOWN (18 sentences)
# test/15703
# 50.00% Category.UNKNOWN (78 sentences)
# test/15703
# 50.00% male (92 sentences)
# test/15704
# 100.00% Category.UNKNOWN (82 sentences)
# test/15707
# 100.00% Category.UNKNOWN (20 sentences)
# test/15708
# 100.00% Category.UNKNOWN (18 sentences)
# test/15709
# 100.00% Category.UNKNOWN (22 sentences)
# test/15710
# 100.00% Category.UNKNOWN (49 sentences)
# test/15713
# 100.00% Category.UNKNOWN (111 sentences)
# test/15715
# 100.00% Category.UNKNOWN (21 sentences)
# test/15717
# 100.00% Category.UNKNOWN (44 sentences)
# test/15719
# 100.00% Category.UNKNOWN (21 sentences)
# test/15720
# 100.00% Category.UNKNOWN (132 sentences)
# test/15721
# 100.00% Category.UNKNOWN (18 sentences)
# test/15723
# 100.00% Category.UNKNOWN (26 sentences)
# test/15725
# 100.00% Category.UNKNOWN (100 sentences)
# test/15726
# 100.00% Category.UNKNOWN (85 sentences)
# test/15727
# 100.00% Category.UNKNOWN (74 sentences)
# test/15728
# 100.00% Category.UNKNOWN (57 sentences)
# test/15729
# 100.00% Category.UNKNOWN (62 sentences)
# test/15732
# 100.00% Category.UNKNOWN (25 sentences)
# test/15733
# 100.00% Category.UNKNOWN (45 sentences)
# test/15736
# 100.00% Category.UNKNOWN (193 sentences)
# test/15737
# 100.00% Category.UNKNOWN (90 sentences)
# test/15739
# 100.00% Category.UNKNOWN (85 sentences)
# test/15742
# 80.00% Category.UNKNOWN (406 sentences)
# test/15742
# 16.00% male (85 sentences)
# test/15742
# 4.00% female (9 sentences)
# test/15749
# 100.00% Category.UNKNOWN (15 sentences)
# test/15751
# 100.00% Category.UNKNOWN (49 sentences)
# test/15753
# 100.00% Category.UNKNOWN (41 sentences)
# test/15757
# 100.00% Category.UNKNOWN (26 sentences)
# test/15759
# 100.00% Category.UNKNOWN (18 sentences)
# test/15762
# 100.00% Category.UNKNOWN (152 sentences)
# test/15767
# 100.00% Category.UNKNOWN (43 sentences)
# test/15768
# 100.00% Category.UNKNOWN (93 sentences)
# test/15769
# 100.00% Category.UNKNOWN (22 sentences)
# test/15772
# 100.00% Category.UNKNOWN (33 sentences)
# test/15777
# 100.00% Category.UNKNOWN (27 sentences)
# test/15778
# 100.00% Category.UNKNOWN (32 sentences)
# test/15780
# 100.00% Category.UNKNOWN (22 sentences)
# test/15782
# 100.00% Category.UNKNOWN (37 sentences)
# test/15785
# 100.00% Category.UNKNOWN (27 sentences)
# test/15790
# 100.00% Category.UNKNOWN (22 sentences)
# test/15793
# 100.00% Category.UNKNOWN (84 sentences)
# test/15797
# 100.00% Category.UNKNOWN (31 sentences)
# test/15798
# 70.00% Category.UNKNOWN (175 sentences)
# test/15798
# 30.00% male (64 sentences)
# test/15800
# 100.00% Category.UNKNOWN (60 sentences)
# test/15801
# 100.00% Category.UNKNOWN (49 sentences)
# test/15803
# 100.00% Category.UNKNOWN (88 sentences)
# test/15804
# 71.43% Category.UNKNOWN (63 sentences)
# test/15804
# 28.57% male (46 sentences)
# test/15805
# 100.00% Category.UNKNOWN (10 sentences)
# test/15807
# 100.00% Category.UNKNOWN (38 sentences)
# test/15808
# 100.00% Category.UNKNOWN (68 sentences)
# test/15810
# 100.00% Category.UNKNOWN (128 sentences)
# test/15811
# 100.00% Category.UNKNOWN (88 sentences)
# test/15816
# 100.00% Category.UNKNOWN (134 sentences)
# test/15817
# 100.00% Category.UNKNOWN (123 sentences)
# test/15819
# 100.00% Category.UNKNOWN (21 sentences)
# test/15821
# 100.00% Category.UNKNOWN (51 sentences)
# test/15822
# 100.00% Category.UNKNOWN (25 sentences)
# test/15823
# 100.00% Category.UNKNOWN (26 sentences)
# test/15829
# 100.00% Category.UNKNOWN (54 sentences)
# test/15831
# 100.00% Category.UNKNOWN (28 sentences)
# test/15832
# 100.00% Category.UNKNOWN (24 sentences)
# test/15833
# 100.00% Category.UNKNOWN (25 sentences)
# test/15834
# 100.00% Category.UNKNOWN (38 sentences)
# test/15836
# 75.00% Category.UNKNOWN (69 sentences)
# test/15836
# 25.00% male (24 sentences)
# test/15838
# 78.57% Category.UNKNOWN (176 sentences)
# test/15838
# 21.43% male (44 sentences)
# test/15840
# 100.00% Category.UNKNOWN (484 sentences)
# test/15841
# 100.00% Category.UNKNOWN (150 sentences)
# test/15842
# 100.00% Category.UNKNOWN (16 sentences)
# test/15844
# 100.00% Category.UNKNOWN (15 sentences)
# test/15845
# 100.00% Category.UNKNOWN (13 sentences)
# test/15846
# 100.00% Category.UNKNOWN (9 sentences)
# test/15847
# 100.00% female (14 sentences)
# test/15851
# 100.00% Category.UNKNOWN (57 sentences)
# test/15852
# 100.00% Category.UNKNOWN (9 sentences)
# test/15853
# 100.00% Category.UNKNOWN (312 sentences)
# test/15854
# 100.00% Category.UNKNOWN (64 sentences)
# test/15855
# 100.00% Category.UNKNOWN (62 sentences)
# test/15856
# 100.00% Category.UNKNOWN (88 sentences)
# test/15858
# 100.00% Category.UNKNOWN (63 sentences)
# test/15859
# 100.00% Category.UNKNOWN (45 sentences)
# test/15860
# 100.00% Category.UNKNOWN (59 sentences)
# test/15861
# 100.00% Category.UNKNOWN (112 sentences)
# test/15863
# 100.00% Category.UNKNOWN (151 sentences)
# test/15864
# 100.00% Category.UNKNOWN (220 sentences)
# test/15865
# 100.00% Category.UNKNOWN (88 sentences)
# test/15866
# 100.00% Category.UNKNOWN (76 sentences)
# test/15867
# 100.00% Category.UNKNOWN (9 sentences)
# test/15868
# 100.00% Category.UNKNOWN (49 sentences)
# test/15869
# 100.00% Category.UNKNOWN (50 sentences)
# test/15870
# 100.00% Category.UNKNOWN (85 sentences)
# test/15871
# 100.00% Category.UNKNOWN (757 sentences)
# test/15872
# 78.57% Category.UNKNOWN (177 sentences)
# test/15872
# 21.43% male (44 sentences)
# test/15874
# 100.00% Category.UNKNOWN (90 sentences)
# test/15875
# 100.00% Category.UNKNOWN (1218 sentences)
# test/15876
# 100.00% Category.UNKNOWN (36 sentences)
# test/15877
# 100.00% Category.UNKNOWN (51 sentences)
# test/15878
# 100.00% Category.UNKNOWN (77 sentences)
# test/15879
# 100.00% Category.UNKNOWN (30 sentences)
# test/15881
# 100.00% Category.UNKNOWN (40 sentences)
# test/15885
# 100.00% Category.UNKNOWN (40 sentences)
# test/15886
# 100.00% Category.UNKNOWN (28 sentences)
# test/15888
# 100.00% Category.UNKNOWN (36 sentences)
# test/15889
# 100.00% Category.UNKNOWN (20 sentences)
# test/15890
# 100.00% Category.UNKNOWN (71 sentences)
# test/15892
# 25.00% male (18 sentences)
# test/15892
# 75.00% Category.UNKNOWN (45 sentences)
# test/15893
# 100.00% Category.UNKNOWN (175 sentences)
# test/15894
# 87.50% Category.UNKNOWN (155 sentences)
# test/15894
# 12.50% male (25 sentences)
# test/15895
# 100.00% Category.UNKNOWN (24 sentences)
# test/15896
# 100.00% Category.UNKNOWN (33 sentences)
# test/15897
# 100.00% Category.UNKNOWN (20 sentences)
# test/15898
# 100.00% Category.UNKNOWN (37 sentences)
# test/15899
# 100.00% Category.UNKNOWN (40 sentences)
# test/15900
# 100.00% Category.UNKNOWN (52 sentences)
# test/15901
# 100.00% Category.UNKNOWN (19 sentences)
# test/15902
# 100.00% Category.UNKNOWN (24 sentences)
# test/15903
# 100.00% Category.UNKNOWN (24 sentences)
# test/15904
# 100.00% Category.UNKNOWN (24 sentences)
# test/15906
# 100.00% Category.UNKNOWN (476 sentences)
# test/15908
# 100.00% Category.UNKNOWN (38 sentences)
# test/15909
# 100.00% Category.UNKNOWN (48 sentences)
# test/15910
# 100.00% Category.UNKNOWN (148 sentences)
# test/15911
# 100.00% Category.UNKNOWN (96 sentences)
# test/15912
# 100.00% Category.UNKNOWN (102 sentences)
# test/15913
# 75.00% male (64 sentences)
# test/15913
# 25.00% Category.UNKNOWN (22 sentences)
# test/15914
# 100.00% Category.UNKNOWN (186 sentences)
# test/15916
# 100.00% Category.UNKNOWN (91 sentences)
# test/15917
# 100.00% Category.UNKNOWN (88 sentences)
# test/15918
# 100.00% Category.UNKNOWN (48 sentences)
# test/15920
# 100.00% Category.UNKNOWN (64 sentences)
# test/15921
# 100.00% Category.UNKNOWN (94 sentences)
# test/15922
# 100.00% Category.UNKNOWN (80 sentences)
# test/15923
# 100.00% Category.UNKNOWN (81 sentences)
# test/15924
# 100.00% Category.UNKNOWN (70 sentences)
# test/15925
# 100.00% Category.UNKNOWN (103 sentences)
# test/15927
# 100.00% Category.UNKNOWN (87 sentences)
# test/15928
# 100.00% Category.UNKNOWN (47 sentences)
# test/15929
# 100.00% Category.UNKNOWN (90 sentences)
# test/15930
# 100.00% Category.UNKNOWN (19 sentences)
# test/15932
# 100.00% Category.UNKNOWN (176 sentences)
# test/15933
# 100.00% Category.UNKNOWN (18 sentences)
# test/15934
# 100.00% Category.UNKNOWN (18 sentences)
# test/15937
# 100.00% Category.UNKNOWN (11 sentences)
# test/15939
# 75.00% Category.UNKNOWN (217 sentences)
# test/15939
# 25.00% male (66 sentences)
# test/15942
# 100.00% Category.UNKNOWN (17 sentences)
# test/15944
# 100.00% Category.UNKNOWN (28 sentences)
# test/15949
# 100.00% Category.UNKNOWN (86 sentences)
# test/15950
# 100.00% Category.UNKNOWN (62 sentences)
# test/15951
# 50.00% male (47 sentences)
# test/15951
# 50.00% Category.UNKNOWN (29 sentences)
# test/15952
# 100.00% Category.UNKNOWN (112 sentences)
# test/15953
# 100.00% Category.UNKNOWN (145 sentences)
# test/15956
# 100.00% Category.UNKNOWN (156 sentences)
# test/15959
# 100.00% Category.UNKNOWN (26 sentences)
# test/15960
# 100.00% Category.UNKNOWN (102 sentences)
# test/15961
# 100.00% Category.UNKNOWN (87 sentences)
# test/15963
# 100.00% Category.UNKNOWN (45 sentences)
# test/15964
# 100.00% Category.UNKNOWN (124 sentences)
# test/15967
# 100.00% Category.UNKNOWN (142 sentences)
# test/15968
# 100.00% Category.UNKNOWN (49 sentences)
# test/15969
# 100.00% Category.UNKNOWN (34 sentences)
# test/15970
# 100.00% Category.UNKNOWN (66 sentences)
# test/15973
# 100.00% Category.UNKNOWN (144 sentences)
# test/15975
# 100.00% Category.UNKNOWN (298 sentences)
# test/15976
# 100.00% Category.UNKNOWN (14 sentences)
# test/15977
# 100.00% Category.UNKNOWN (13 sentences)
# test/15978
# 100.00% Category.UNKNOWN (14 sentences)
# test/15979
# 20.00% male (34 sentences)
# test/15979
# 80.00% Category.UNKNOWN (54 sentences)
# test/15980
# 100.00% Category.UNKNOWN (23 sentences)
# test/15981
# 100.00% Category.UNKNOWN (18 sentences)
# test/15984
# 100.00% Category.UNKNOWN (18 sentences)
# test/15985
# 100.00% Category.UNKNOWN (54 sentences)
# test/15987
# 86.67% Category.UNKNOWN (258 sentences)
# test/15987
# 13.33% male (43 sentences)
# test/15988
# 100.00% Category.UNKNOWN (101 sentences)
# test/15989
# 100.00% Category.UNKNOWN (62 sentences)
# test/15993
# 100.00% Category.UNKNOWN (76 sentences)
# test/15995
# 100.00% Category.UNKNOWN (47 sentences)
# test/15996
# 100.00% Category.UNKNOWN (47 sentences)
# test/15997
# 100.00% Category.UNKNOWN (50 sentences)
# test/15999
# 100.00% Category.UNKNOWN (93 sentences)
# test/16002
# 100.00% Category.UNKNOWN (13 sentences)
# test/16003
# 100.00% Category.UNKNOWN (19 sentences)
# test/16004
# 100.00% Category.UNKNOWN (11 sentences)
# test/16005
# 100.00% Category.UNKNOWN (239 sentences)
# test/16006
# 40.00% Category.UNKNOWN (153 sentences)
# test/16006
# 60.00% male (197 sentences)
# test/16007
# 100.00% Category.UNKNOWN (70 sentences)
# test/16009
# 94.74% Category.UNKNOWN (410 sentences)
# test/16009
# 5.26% male (16 sentences)
# test/16012
# 100.00% Category.UNKNOWN (23 sentences)
# test/16013
# 100.00% Category.UNKNOWN (36 sentences)
# test/16014
# 100.00% Category.UNKNOWN (2 sentences)
# test/16015
# 100.00% Category.UNKNOWN (15 sentences)
# test/16016
# 100.00% Category.UNKNOWN (47 sentences)
# test/16021
# 100.00% Category.UNKNOWN (82 sentences)
# test/16022
# 100.00% Category.UNKNOWN (43 sentences)
# test/16023
# 60.00% Category.UNKNOWN (131 sentences)
# test/16023
# 40.00% male (88 sentences)
# test/16026
# 100.00% Category.UNKNOWN (82 sentences)
# test/16029
# 100.00% Category.UNKNOWN (98 sentences)
# test/16030
# 100.00% Category.UNKNOWN (55 sentences)
# test/16033
# 100.00% Category.UNKNOWN (9 sentences)
# test/16037
# 100.00% Category.UNKNOWN (48 sentences)
# test/16040
# 100.00% Category.UNKNOWN (2 sentences)
# test/16041
# 100.00% Category.UNKNOWN (30 sentences)
# test/16045
# 100.00% Category.UNKNOWN (20 sentences)
# test/16052
# 100.00% Category.UNKNOWN (90 sentences)
# test/16053
# 81.82% Category.UNKNOWN (434 sentences)
# test/16053
# 4.55% Category.BOTH (28 sentences)
# test/16053
# 4.55% female (27 sentences)
# test/16053
# 9.09% male (58 sentences)
# test/16055
# 100.00% Category.UNKNOWN (31 sentences)
# test/16063
# 100.00% Category.UNKNOWN (70 sentences)
# test/16066
# 100.00% Category.UNKNOWN (11 sentences)
# test/16067
# 100.00% Category.UNKNOWN (11 sentences)
# test/16068
# 100.00% Category.UNKNOWN (198 sentences)
# test/16069
# 100.00% Category.UNKNOWN (46 sentences)
# test/16071
# 100.00% Category.UNKNOWN (134 sentences)
# test/16072
# 75.76% Category.UNKNOWN (564 sentences)
# test/16072
# 24.24% male (192 sentences)
# test/16074
# 100.00% Category.UNKNOWN (87 sentences)
# test/16075
# 92.86% Category.UNKNOWN (281 sentences)
# test/16075
# 7.14% male (31 sentences)
# test/16076
# 100.00% Category.UNKNOWN (162 sentences)
# test/16077
# 50.00% male (73 sentences)
# test/16077
# 50.00% Category.UNKNOWN (60 sentences)
# test/16079
# 100.00% Category.UNKNOWN (77 sentences)
# test/16080
# 100.00% Category.UNKNOWN (88 sentences)
# test/16083
# 33.33% Category.UNKNOWN (29 sentences)
# test/16083
# 66.67% male (52 sentences)
# test/16086
# 100.00% Category.UNKNOWN (94 sentences)
# test/16088
# 83.33% Category.UNKNOWN (131 sentences)
# test/16088
# 16.67% male (37 sentences)
# test/16091
# 100.00% Category.UNKNOWN (78 sentences)
# test/16093
# 82.35% Category.UNKNOWN (257 sentences)
# test/16093
# 17.65% male (80 sentences)
# test/16094
# 64.29% Category.UNKNOWN (216 sentences)
# test/16094
# 35.71% male (129 sentences)
# test/16095
# 43.75% male (176 sentences)
# test/16095
# 56.25% Category.UNKNOWN (199 sentences)
# test/16096
# 100.00% Category.UNKNOWN (83 sentences)
# test/16097
# 100.00% Category.UNKNOWN (253 sentences)
# test/16098
# 100.00% Category.UNKNOWN (31 sentences)
# test/16099
# 90.00% Category.UNKNOWN (183 sentences)
# test/16099
# 10.00% male (26 sentences)
# test/16100
# 100.00% Category.UNKNOWN (58 sentences)
# test/16103
# 100.00% Category.UNKNOWN (231 sentences)
# test/16106
# 100.00% Category.UNKNOWN (13 sentences)
# test/16107
# 100.00% Category.UNKNOWN (89 sentences)
# test/16108
# 100.00% Category.UNKNOWN (252 sentences)
# test/16110
# 100.00% Category.UNKNOWN (30 sentences)
# test/16111
# 100.00% Category.UNKNOWN (82 sentences)
# test/16112
# 89.47% Category.UNKNOWN (385 sentences)
# test/16112
# 10.53% male (41 sentences)
# test/16115
# 100.00% Category.UNKNOWN (59 sentences)
# test/16117
# 100.00% Category.UNKNOWN (93 sentences)
# test/16118
# 100.00% Category.UNKNOWN (285 sentences)
# test/16119
# 100.00% Category.UNKNOWN (172 sentences)
# test/16120
# 100.00% Category.UNKNOWN (45 sentences)
# test/16122
# 100.00% Category.UNKNOWN (45 sentences)
# test/16123
# 100.00% Category.UNKNOWN (133 sentences)
# test/16125
# 100.00% Category.UNKNOWN (78 sentences)
# test/16126
# 100.00% male (80 sentences)
# test/16130
# 72.22% Category.UNKNOWN (294 sentences)
# test/16130
# 27.78% male (121 sentences)
# test/16133
# 100.00% Category.UNKNOWN (67 sentences)
# test/16134
# 100.00% Category.UNKNOWN (59 sentences)
# test/16136
# 100.00% Category.UNKNOWN (92 sentences)
# test/16139
# 100.00% Category.UNKNOWN (477 sentences)
# test/16140
# 100.00% Category.UNKNOWN (173 sentences)
# test/16141
# 100.00% Category.UNKNOWN (80 sentences)
# test/16142
# 100.00% Category.UNKNOWN (59 sentences)
# test/16143
# 100.00% Category.UNKNOWN (71 sentences)
# test/16144
# 54.55% male (170 sentences)
# test/16144
# 45.45% Category.UNKNOWN (95 sentences)
# test/16145
# 100.00% Category.UNKNOWN (85 sentences)
# test/16146
# 100.00% Category.UNKNOWN (259 sentences)
# test/16147
# 100.00% Category.UNKNOWN (161 sentences)
# test/16148
# 75.00% Category.UNKNOWN (56 sentences)
# test/16148
# 25.00% male (23 sentences)
# test/16149
# 25.00% male (38 sentences)
# test/16149
# 75.00% Category.UNKNOWN (45 sentences)
# test/16150
# 100.00% Category.UNKNOWN (92 sentences)
# test/16152
# 100.00% Category.UNKNOWN (71 sentences)
# test/16155
# 100.00% Category.UNKNOWN (142 sentences)
# test/16158
# 100.00% Category.UNKNOWN (628 sentences)
# test/16159
# 100.00% Category.UNKNOWN (95 sentences)
# test/16161
# 100.00% Category.UNKNOWN (171 sentences)
# test/16162
# 100.00% Category.UNKNOWN (137 sentences)
# test/16163
# 88.00% Category.UNKNOWN (487 sentences)
# test/16163
# 8.00% female (50 sentences)
# test/16163
# 4.00% male (7 sentences)
# test/16164
# 100.00% Category.UNKNOWN (187 sentences)
# test/16166
# 91.67% Category.UNKNOWN (217 sentences)
# test/16166
# 8.33% male (24 sentences)
# test/16170
# 75.00% Category.UNKNOWN (73 sentences)
# test/16170
# 25.00% male (21 sentences)
# test/16171
# 100.00% Category.UNKNOWN (384 sentences)
# test/16172
# 100.00% Category.UNKNOWN (13 sentences)
# test/16173
# 100.00% Category.UNKNOWN (85 sentences)
# test/16175
# 100.00% Category.UNKNOWN (114 sentences)
# test/16176
# 83.33% Category.UNKNOWN (275 sentences)
# test/16176
# 16.67% male (56 sentences)
# test/16177
# 100.00% Category.UNKNOWN (115 sentences)
# test/16179
# 100.00% Category.UNKNOWN (173 sentences)
# test/16180
# 100.00% Category.UNKNOWN (74 sentences)
# test/16185
# 100.00% Category.UNKNOWN (47 sentences)
# test/16188
# 100.00% Category.UNKNOWN (61 sentences)
# test/16189
# 100.00% Category.UNKNOWN (82 sentences)
# test/16190
# 86.96% Category.UNKNOWN (348 sentences)
# test/16190
# 13.04% male (75 sentences)
# test/16193
# 100.00% Category.UNKNOWN (22 sentences)
# test/16194
# 100.00% Category.UNKNOWN (26 sentences)
# test/16195
# 75.00% Category.UNKNOWN (144 sentences)
# test/16195
# 25.00% male (75 sentences)
# test/16196
# 85.71% Category.UNKNOWN (137 sentences)
# test/16196
# 14.29% male (25 sentences)
# test/16197
# 100.00% Category.UNKNOWN (125 sentences)
# test/16200
# 77.78% Category.UNKNOWN (488 sentences)
# test/16200
# 22.22% male (144 sentences)
# test/16201
# 28.57% male (41 sentences)
# test/16201
# 71.43% Category.UNKNOWN (96 sentences)
# test/16202
# 100.00% Category.UNKNOWN (18 sentences)
# test/16203
# 100.00% Category.UNKNOWN (91 sentences)
# test/16206
# 100.00% male (30 sentences)
# test/16207
# 100.00% Category.UNKNOWN (109 sentences)
# test/16210
# 100.00% Category.UNKNOWN (58 sentences)
# test/16211
# 100.00% Category.UNKNOWN (254 sentences)
# test/16212
# 100.00% Category.UNKNOWN (52 sentences)
# test/16213
# 66.67% Category.UNKNOWN (77 sentences)
# test/16213
# 33.33% male (48 sentences)
# test/16214
# 38.46% male (100 sentences)
# test/16214
# 61.54% Category.UNKNOWN (194 sentences)
# test/16215
# 72.22% Category.UNKNOWN (294 sentences)
# test/16215
# 27.78% male (121 sentences)
# test/16216
# 76.19% male (454 sentences)
# test/16216
# 23.81% Category.UNKNOWN (92 sentences)
# test/16219
# 100.00% Category.UNKNOWN (54 sentences)
# test/16221
# 100.00% Category.UNKNOWN (24 sentences)
# test/16223
# 100.00% Category.UNKNOWN (11 sentences)
# test/16225
# 40.00% male (54 sentences)
# test/16225
# 60.00% Category.UNKNOWN (48 sentences)
# test/16226
# 95.45% Category.UNKNOWN (452 sentences)
# test/16226
# 4.55% male (20 sentences)
# test/16228
# 100.00% Category.UNKNOWN (10 sentences)
# test/16230
# 100.00% Category.UNKNOWN (26 sentences)
# test/16232
# 100.00% Category.UNKNOWN (79 sentences)
# test/16233
# 85.71% Category.UNKNOWN (103 sentences)
# test/16233
# 14.29% male (26 sentences)
# test/16234
# 100.00% Category.UNKNOWN (37 sentences)
# test/16236
# 100.00% Category.UNKNOWN (69 sentences)
# test/16238
# 100.00% Category.UNKNOWN (294 sentences)
# test/16241
# 100.00% Category.UNKNOWN (152 sentences)
# test/16243
# 100.00% Category.UNKNOWN (30 sentences)
# test/16244
# 100.00% Category.UNKNOWN (34 sentences)
# test/16246
# 100.00% Category.UNKNOWN (51 sentences)
# test/16247
# 100.00% Category.UNKNOWN (50 sentences)
# test/16248
# 87.50% Category.UNKNOWN (139 sentences)
# test/16248
# 12.50% male (21 sentences)
# test/16250
# 100.00% Category.UNKNOWN (100 sentences)
# test/16251
# 100.00% Category.UNKNOWN (83 sentences)
# test/16252
# 66.67% Category.UNKNOWN (94 sentences)
# test/16252
# 33.33% male (56 sentences)
# test/16255
# 100.00% Category.UNKNOWN (47 sentences)
# test/16256
# 100.00% Category.UNKNOWN (178 sentences)
# test/16257
# 100.00% Category.UNKNOWN (231 sentences)
# test/16258
# 100.00% Category.UNKNOWN (75 sentences)
# test/16260
# 100.00% Category.UNKNOWN (9 sentences)
# test/16262
# 100.00% Category.UNKNOWN (50 sentences)
# test/16263
# 100.00% Category.UNKNOWN (19 sentences)
# test/16264
# ...
# 100.00% Category.UNKNOWN (101 sentences)
# training/9619
# 100.00% Category.UNKNOWN (34 sentences)
# training/9625
# 100.00% Category.UNKNOWN (48 sentences)
# training/9626
# 100.00% Category.UNKNOWN (11 sentences)
# training/9628
# 100.00% Category.UNKNOWN (149 sentences)
# training/963
# 100.00% Category.UNKNOWN (87 sentences)
# training/9634
# 100.00% Category.UNKNOWN (247 sentences)
# training/9635
# 100.00% Category.UNKNOWN (9 sentences)
# training/9637
# 84.62% Category.UNKNOWN (292 sentences)
# training/9637
# 15.38% male (61 sentences)
# training/9638
# 57.69% Category.UNKNOWN (304 sentences)
# training/9638
# 42.31% male (190 sentences)
# training/9639
# 92.31% Category.UNKNOWN (296 sentences)
# training/9639
# 7.69% male (27 sentences)
# training/9640
# 100.00% Category.UNKNOWN (80 sentences)
# training/9641
# 100.00% Category.UNKNOWN (180 sentences)
# training/9642
# 100.00% Category.UNKNOWN (88 sentences)
# training/9644
# 100.00% Category.UNKNOWN (32 sentences)
# training/9647
# 100.00% Category.UNKNOWN (29 sentences)
# training/9650
# 94.44% Category.UNKNOWN (363 sentences)
# training/9650
# 5.56% male (28 sentences)
# training/9652
# 100.00% Category.UNKNOWN (32 sentences)
# training/9654
# 40.00% male (46 sentences)
# training/9654
# 60.00% Category.UNKNOWN (48 sentences)
# training/9656
# 100.00% Category.UNKNOWN (223 sentences)
# training/9657
# 100.00% Category.UNKNOWN (147 sentences)
# training/9661
# 100.00% Category.UNKNOWN (75 sentences)
# training/9667
# 100.00% Category.UNKNOWN (587 sentences)
# training/9668
# 100.00% Category.UNKNOWN (81 sentences)
# training/9671
# 100.00% Category.UNKNOWN (18 sentences)
# training/9674
# 100.00% Category.UNKNOWN (175 sentences)
# training/9675
# 100.00% Category.UNKNOWN (83 sentences)
# training/9677
# 100.00% Category.UNKNOWN (58 sentences)
# training/9678
# 100.00% Category.UNKNOWN (35 sentences)
# training/968
# 100.00% Category.UNKNOWN (39 sentences)
# training/9680
# 83.33% Category.UNKNOWN (102 sentences)
# training/9680
# 16.67% male (19 sentences)
# training/9681
# 100.00% Category.UNKNOWN (88 sentences)
# training/9682
# 100.00% Category.UNKNOWN (40 sentences)
# training/9686
# 100.00% male (13 sentences)
# training/9689
# 54.55% male (155 sentences)
# training/9689
# 45.45% Category.UNKNOWN (128 sentences)
# training/969
# 50.00% male (123 sentences)
# training/969
# 50.00% Category.UNKNOWN (135 sentences)
# training/9697
# 25.00% male (24 sentences)
# training/9697
# 75.00% Category.UNKNOWN (64 sentences)
# training/9698
# 100.00% Category.UNKNOWN (10 sentences)
# training/9699
# 100.00% Category.UNKNOWN (10 sentences)
# training/97
# 100.00% Category.UNKNOWN (201 sentences)
# training/9700
# 100.00% Category.UNKNOWN (135 sentences)
# training/9701
# 36.36% Category.UNKNOWN (89 sentences)
# training/9701
# 63.64% male (146 sentences)
# training/9704
# 66.67% Category.UNKNOWN (172 sentences)
# training/9704
# 33.33% male (100 sentences)
# training/9705
# 100.00% Category.UNKNOWN (82 sentences)
# training/9706
# 10.53% male (41 sentences)
# training/9706
# 89.47% Category.UNKNOWN (327 sentences)
# training/9707
# 100.00% Category.UNKNOWN (78 sentences)
# training/971
# 100.00% Category.UNKNOWN (165 sentences)
# training/9712
# 50.00% Category.UNKNOWN (47 sentences)
# training/9712
# 50.00% male (44 sentences)
# training/9718
# 66.67% Category.UNKNOWN (52 sentences)
# training/9718
# 33.33% male (35 sentences)
# training/972
# 100.00% Category.UNKNOWN (26 sentences)
# training/9720
# 71.43% Category.UNKNOWN (113 sentences)
# training/9720
# 28.57% male (35 sentences)
# training/9723
# 100.00% Category.UNKNOWN (12 sentences)
# training/9727
# 100.00% Category.UNKNOWN (9 sentences)
# training/9728
# 100.00% Category.UNKNOWN (91 sentences)
# training/9729
# 25.00% female (24 sentences)
# training/9729
# 75.00% Category.UNKNOWN (47 sentences)
# training/9730
# 100.00% Category.UNKNOWN (166 sentences)
# training/9731
# 100.00% Category.UNKNOWN (18 sentences)
# training/9733
# 93.75% Category.UNKNOWN (590 sentences)
# training/9733
# 6.25% male (35 sentences)
# training/9734
# 100.00% Category.UNKNOWN (315 sentences)
# training/9735
# 100.00% Category.UNKNOWN (13 sentences)
# training/9736
# 100.00% Category.UNKNOWN (278 sentences)
# training/9737
# 100.00% Category.UNKNOWN (13 sentences)
# training/9738
# 66.67% Category.UNKNOWN (58 sentences)
# training/9738
# 33.33% male (28 sentences)
# training/974
# 100.00% Category.UNKNOWN (208 sentences)
# training/9741
# 100.00% Category.UNKNOWN (82 sentences)
# training/9742
# 100.00% Category.UNKNOWN (278 sentences)
# training/9744
# 100.00% Category.UNKNOWN (42 sentences)
# training/9745
# 100.00% Category.UNKNOWN (53 sentences)
# training/9746
# 100.00% Category.UNKNOWN (189 sentences)
# training/9747
# 100.00% Category.UNKNOWN (11 sentences)
# training/9748
# 100.00% Category.UNKNOWN (10 sentences)
# training/9749
# 8.33% female (47 sentences)
# training/9749
# 79.17% Category.UNKNOWN (390 sentences)
# training/9749
# 12.50% male (57 sentences)
# training/9751
# 75.00% Category.UNKNOWN (100 sentences)
# training/9751
# 25.00% male (40 sentences)
# training/9752
# 100.00% Category.UNKNOWN (88 sentences)
# training/9753
# 100.00% Category.UNKNOWN (78 sentences)
# training/9754
# 95.83% Category.UNKNOWN (500 sentences)
# training/9754
# 4.17% male (23 sentences)
# training/9755
# 90.00% Category.UNKNOWN (215 sentences)
# training/9755
# 10.00% male (37 sentences)
# training/9756
# 100.00% Category.UNKNOWN (54 sentences)
# training/976
# 100.00% Category.UNKNOWN (22 sentences)
# training/9760
# 5.56% male (40 sentences)
# training/9760
# 94.44% Category.UNKNOWN (335 sentences)
# training/9761
# 100.00% Category.UNKNOWN (313 sentences)
# training/9763
# 61.54% Category.UNKNOWN (176 sentences)
# training/9763
# 38.46% male (97 sentences)
# training/9764
# 88.46% Category.UNKNOWN (537 sentences)
# training/9764
# 11.54% male (81 sentences)
# training/9767
# 100.00% Category.UNKNOWN (24 sentences)
# training/9768
# 100.00% Category.UNKNOWN (24 sentences)
# training/9769
# 100.00% Category.UNKNOWN (258 sentences)
# training/977
# 62.50% Category.UNKNOWN (169 sentences)
# training/977
# 37.50% male (83 sentences)
# training/9770
# 100.00% Category.UNKNOWN (226 sentences)
# training/9771
# 100.00% Category.UNKNOWN (151 sentences)
# training/9772
# 100.00% Category.UNKNOWN (13 sentences)
# training/9773
# 100.00% Category.UNKNOWN (14 sentences)
# training/9777
# 50.00% Category.UNKNOWN (47 sentences)
# training/9777
# 50.00% male (44 sentences)
# training/9779
# 100.00% Category.UNKNOWN (135 sentences)
# training/978
# 100.00% Category.UNKNOWN (81 sentences)
# training/9781
# 100.00% Category.UNKNOWN (26 sentences)
# training/9782
# 100.00% Category.UNKNOWN (384 sentences)
# training/9783
# 100.00% Category.UNKNOWN (82 sentences)
# training/9784
# 85.71% Category.UNKNOWN (415 sentences)
# training/9784
# 14.29% male (71 sentences)
# training/9787
# 100.00% Category.UNKNOWN (41 sentences)
# training/9792
# 100.00% Category.UNKNOWN (127 sentences)
# training/9793
# 100.00% Category.UNKNOWN (432 sentences)
# training/9795
# 46.15% male (139 sentences)
# training/9795
# 53.85% Category.UNKNOWN (144 sentences)
# training/9797
# 55.56% male (126 sentences)
# training/9797
# 44.44% Category.UNKNOWN (91 sentences)
# training/9799
# 75.00% Category.UNKNOWN (140 sentences)
# training/9799
# 25.00% male (58 sentences)
# training/98
# 100.00% Category.UNKNOWN (31 sentences)
# training/9801
# 66.67% Category.UNKNOWN (52 sentences)
# training/9801
# 33.33% male (35 sentences)
# training/9804
# 50.00% male (93 sentences)
# training/9804
# 50.00% Category.UNKNOWN (80 sentences)
# training/9805
# 100.00% Category.UNKNOWN (11 sentences)
# training/9807
# 100.00% Category.UNKNOWN (39 sentences)
# training/9809
# 100.00% Category.UNKNOWN (50 sentences)
# training/981
# 100.00% Category.UNKNOWN (20 sentences)
# training/9810
# 100.00% Category.UNKNOWN (44 sentences)
# training/9812
# 100.00% Category.UNKNOWN (63 sentences)
# training/9814
# 100.00% Category.UNKNOWN (45 sentences)
# training/9815
# 100.00% Category.UNKNOWN (13 sentences)
# training/9816
# 25.00% male (24 sentences)
# training/9816
# 75.00% Category.UNKNOWN (64 sentences)
# training/9818
# 100.00% Category.UNKNOWN (73 sentences)
# training/982
# 22.22% Category.UNKNOWN (36 sentences)
# training/982
# 77.78% male (154 sentences)
# training/9821
# 100.00% Category.UNKNOWN (190 sentences)
# training/9822
# 100.00% Category.UNKNOWN (114 sentences)
# training/9823
# 100.00% Category.UNKNOWN (12 sentences)
# training/9824
# 100.00% Category.UNKNOWN (13 sentences)
# training/9825
# 100.00% Category.UNKNOWN (31 sentences)
# training/9827
# 100.00% Category.UNKNOWN (21 sentences)
# training/9829
# 100.00% Category.UNKNOWN (59 sentences)
# training/983
# 100.00% Category.UNKNOWN (327 sentences)
# training/9833
# 100.00% Category.UNKNOWN (144 sentences)
# training/9834
# 100.00% Category.UNKNOWN (63 sentences)
# training/9836
# 100.00% Category.UNKNOWN (160 sentences)
# training/9837
# 100.00% Category.UNKNOWN (12 sentences)
# training/9839
# 100.00% Category.UNKNOWN (62 sentences)
# training/984
# 100.00% Category.UNKNOWN (65 sentences)
# training/9841
# 60.00% Category.UNKNOWN (120 sentences)
# training/9841
# 40.00% male (87 sentences)
# training/9844
# 100.00% Category.UNKNOWN (65 sentences)
# training/9847
# 75.00% Category.UNKNOWN (68 sentences)
# training/9847
# 25.00% male (31 sentences)
# training/9848
# 84.62% Category.UNKNOWN (528 sentences)
# training/9848
# 15.38% male (83 sentences)
# training/9849
# 100.00% Category.UNKNOWN (114 sentences)
# training/985
# 100.00% Category.UNKNOWN (9 sentences)
# training/9850
# 100.00% Category.UNKNOWN (55 sentences)
# training/9851
# 100.00% Category.UNKNOWN (14 sentences)
# training/9852
# 100.00% Category.UNKNOWN (11 sentences)
# training/9853
# 75.00% Category.UNKNOWN (140 sentences)
# training/9853
# 25.00% male (58 sentences)
# training/9855
# 100.00% Category.UNKNOWN (67 sentences)
# training/9857
# 100.00% Category.UNKNOWN (13 sentences)
# training/9858
# 100.00% Category.UNKNOWN (67 sentences)
# training/986
# 100.00% Category.UNKNOWN (47 sentences)
# training/9860
# 100.00% Category.UNKNOWN (38 sentences)
# training/9861
# 100.00% Category.UNKNOWN (154 sentences)
# training/9862
# 100.00% Category.UNKNOWN (8 sentences)
# training/9864
# 55.56% Category.UNKNOWN (126 sentences)
# training/9864
# 44.44% male (98 sentences)
# training/9865
# 100.00% Category.UNKNOWN (62 sentences)
# training/9866
# 92.31% Category.UNKNOWN (224 sentences)
# training/9866
# 7.69% female (26 sentences)
# training/9867
# 100.00% Category.UNKNOWN (78 sentences)
# training/9868
# 100.00% Category.UNKNOWN (23 sentences)
# training/9869
# 36.36% male (68 sentences)
# training/9869
# 63.64% Category.UNKNOWN (132 sentences)
# training/9871
# 77.78% Category.UNKNOWN (133 sentences)
# training/9871
# 22.22% male (48 sentences)
# training/9872
# 100.00% Category.UNKNOWN (87 sentences)
# training/9874
# 100.00% Category.UNKNOWN (183 sentences)
# training/9875
# 100.00% Category.UNKNOWN (28 sentences)
# training/9878
# 100.00% Category.UNKNOWN (19 sentences)
# training/988
# 75.00% Category.UNKNOWN (101 sentences)
# training/988
# 25.00% male (40 sentences)
# training/9880
# 100.00% Category.UNKNOWN (40 sentences)
# training/9884
# 100.00% Category.UNKNOWN (51 sentences)
# training/9891
# 100.00% Category.UNKNOWN (96 sentences)
# training/9892
# 12.50% male (27 sentences)
# training/9892
# 87.50% Category.UNKNOWN (182 sentences)
# training/9893
# 100.00% Category.UNKNOWN (67 sentences)
# training/9894
# 100.00% Category.UNKNOWN (37 sentences)
# training/9896
# 100.00% Category.UNKNOWN (32 sentences)
# training/9897
# 75.00% Category.UNKNOWN (100 sentences)
# training/9897
# 25.00% male (40 sentences)
# training/99
# 100.00% Category.UNKNOWN (1 sentences)
# training/9901
# 100.00% Category.UNKNOWN (21 sentences)
# training/9902
# 100.00% Category.UNKNOWN (17 sentences)
# training/9903
# 100.00% Category.UNKNOWN (81 sentences)
# training/9904
# 100.00% Category.UNKNOWN (24 sentences)
# training/9905
# 100.00% Category.UNKNOWN (174 sentences)
# training/9906
# 50.00% Category.UNKNOWN (63 sentences)
# training/9906
# 50.00% female (57 sentences)
# training/9907
# 41.67% male (162 sentences)
# training/9907
# 58.33% Category.UNKNOWN (152 sentences)
# training/9909
# 100.00% Category.UNKNOWN (59 sentences)
# training/991
# 66.67% Category.UNKNOWN (80 sentences)
# training/991
# 33.33% male (83 sentences)
# training/9912
# 100.00% Category.UNKNOWN (91 sentences)
# training/9913
# 83.33% Category.UNKNOWN (64 sentences)
# training/9913
# 16.67% male (30 sentences)
# training/9914
# 100.00% Category.UNKNOWN (110 sentences)
# training/9915
# 100.00% Category.UNKNOWN (88 sentences)
# training/9918
# 100.00% Category.UNKNOWN (55 sentences)
# training/9919
# 100.00% Category.UNKNOWN (55 sentences)
# training/9920
# 100.00% Category.UNKNOWN (49 sentences)
# training/9923
# 54.55% Category.UNKNOWN (135 sentences)
# training/9923
# 45.45% male (135 sentences)
# training/9925
# 100.00% Category.UNKNOWN (39 sentences)
# training/9926
# 60.00% male (62 sentences)
# training/9926
# 40.00% Category.UNKNOWN (23 sentences)
# training/9927
# 100.00% Category.UNKNOWN (125 sentences)
# training/9928
# 100.00% Category.UNKNOWN (187 sentences)
# training/9929
# 100.00% Category.UNKNOWN (68 sentences)
# training/9930
# 100.00% Category.UNKNOWN (46 sentences)
# training/9933
# 100.00% Category.UNKNOWN (165 sentences)
# training/9934
# 100.00% Category.UNKNOWN (10 sentences)
# training/9936
# 100.00% Category.UNKNOWN (17 sentences)
# training/9937
# 100.00% Category.UNKNOWN (66 sentences)
# training/9939
# 100.00% Category.UNKNOWN (15 sentences)
# training/9940
# 36.36% male (108 sentences)
# training/9940
# 63.64% Category.UNKNOWN (168 sentences)
# training/9941
# 100.00% Category.UNKNOWN (33 sentences)
# training/9942
# 100.00% Category.UNKNOWN (10 sentences)
# training/9943
# 100.00% Category.UNKNOWN (83 sentences)
# training/9946
# 81.25% Category.UNKNOWN (312 sentences)
# training/9946
# 18.75% male (55 sentences)
# training/9947
# 84.62% Category.UNKNOWN (186 sentences)
# training/9947
# 15.38% male (49 sentences)
# training/995
# 100.00% Category.UNKNOWN (61 sentences)
# training/9952
# 100.00% Category.UNKNOWN (178 sentences)
# training/9953
# 10.00% male (31 sentences)
# training/9953
# 90.00% Category.UNKNOWN (241 sentences)
# training/9954
# 86.67% Category.UNKNOWN (225 sentences)
# training/9954
# 13.33% male (59 sentences)
# training/9955
# 100.00% Category.UNKNOWN (10 sentences)
# training/9956
# 100.00% Category.UNKNOWN (129 sentences)
# training/9957
# 71.43% male (108 sentences)
# training/9957
# 28.57% Category.UNKNOWN (35 sentences)
# training/9958
# 100.00% Category.UNKNOWN (13 sentences)
# training/9959
# 100.00% Category.UNKNOWN (200 sentences)
# training/9961
# 100.00% Category.UNKNOWN (45 sentences)
# training/9963
# 100.00% Category.UNKNOWN (47 sentences)
# training/9964
# 100.00% Category.UNKNOWN (21 sentences)
# training/9965
# 100.00% Category.UNKNOWN (20 sentences)
# training/9967
# 100.00% Category.UNKNOWN (134 sentences)
# training/9970
# 100.00% Category.UNKNOWN (31 sentences)
# training/9971
# 100.00% Category.UNKNOWN (126 sentences)
# training/9972
# 100.00% Category.UNKNOWN (8 sentences)
# training/9973
# 100.00% Category.UNKNOWN (42 sentences)
# training/9974
# 100.00% Category.UNKNOWN (79 sentences)
# training/9975
# 92.59% Category.UNKNOWN (575 sentences)
# training/9975
# 7.41% male (52 sentences)
# training/9976
# 66.67% Category.UNKNOWN (68 sentences)
# training/9976
# 33.33% male (20 sentences)
# training/9977
# 60.00% male (60 sentences)
# training/9977
# 40.00% Category.UNKNOWN (20 sentences)
# training/9978
# 64.00% male (418 sentences)
# training/9978
# 36.00% Category.UNKNOWN (210 sentences)
# training/998
# 100.00% Category.UNKNOWN (50 sentences)
# training/9981
# 100.00% Category.UNKNOWN (77 sentences)
# training/9982
# 100.00% Category.UNKNOWN (80 sentences)
# training/9984
# 100.00% Category.UNKNOWN (82 sentences)
# training/9985
# 100.00% Category.UNKNOWN (19 sentences)
# training/9988
# 50.00% female (26 sentences)
# training/9988
# 50.00% Category.UNKNOWN (14 sentences)
# training/9989
# 100.00% Category.UNKNOWN (78 sentences)
# training/999
# 100.00% Category.UNKNOWN (35 sentences)
# training/9992
# 100.00% Category.UNKNOWN (17 sentences)
# training/9993
# 100.00% Category.UNKNOWN (17 sentences)
# training/9994
# 100.00% Category.UNKNOWN (33 sentences)
# training/9995
# 100.00% Category.UNKNOWN (21 sentences)
# Category.UNKNOWN
# 	said,mln,dlrs,lt,pct,year,us,company,net,vs,cts,1986,inc,would,billion,last,corp,bank,shr,share,
# male
# 	said,would,spokesman,chairman,us,company,year,pct,told,added,dlrs,trade,also,mln,lt,market,new,oil,last,could,
# female
# 	said,spokeswoman,dlrs,would,company,mln,lt,us,market,last,year,told,pct,two,billion,added,trade,1986,share,talks,
# Category.BOTH
# 	said,told,company,net,miss,lt,inc,mln,bank,sister,international,world,shares,women,week,dlrs,spokesman,projections,fed,billion,
