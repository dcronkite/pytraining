# %% [markdown]
# # Extras: Lambda/Yield/Docs
#
# * Lambda expressions
# * Yield
# * Python online documentation

# %% [markdown]
# ## Lambda: nameless functions

# %%
f = lambda : 0

# %%
f()
# Out:
# 0

# %%
def combine(func, x=0, y=0):
    return func(x, y)

# %%
# How can we call combine directly?
combine(lambda x, y: x + y)
# Out:
# 0

# %%
combine(lambda x, y: x + y, 1, 2)
# Out:
# 3

# %%
with open(r'..\data\dickens.txt') as fh:
    words = fh.read().lower().split()

# %%
# count words
count = {}
for word in words:
    # how?
    if word in count:
        count[word] += 1
    else:
        count[word] = 0

# %%
sorted(count.items())
# Out:
# [('"\'and', 0),
#  ('"a', 15),
#  ('"ah!"', 0),
#  ('"all', 1),
#  ('"always', 0),
#  ('"am', 1),
#  ('"an', 0),
#  ('"and', 30),
#  ('"answer', 0),
#  ('"are', 5),
#  ('"as', 0),
#  ('"ask', 0),
#  ('"at', 2),
#  ('"bad,"', 0),
#  ('"bah!"', 1),
#  ('"bear', 0),
#  ('"because', 3),
#  ('"because,"', 0),
#  ('"bed-curtains!"', 1),
#  ('"before', 1),
#  ('"belle,"', 0),
#  ('"bless', 0),
#  ('"bob"', 0),
#  ('"bonneted"', 0),
#  ('"both', 0),
#  ('"bring', 0),
#  ('"business!"', 0),
#  ('"but', 14),
#  ('"by', 0),
#  ('"came', 0),
#  ('"can', 0),
#  ('"christmas', 2),
#  ('"clear', 0),
#  ('"cold,', 0),
#  ('"come', 3),
#  ('"come,', 0),
#  ('"conduct', 0),
#  ('"couldn\'t', 0),
#  ('"cut"--cut', 0),
#  ('"dear,', 0),
#  ('"dick', 0),
#  ('"ding,', 3),
#  ('"do', 3),
#  ('"don\'t', 5),
#  ('"dreadful', 0),
#  ('"eh?"', 0),
#  ('"even', 0),
#  ('"every', 1),
#  ('"everybody', 0),
#  ('"expect', 0),
#  ('"for', 3),
#  ('"forgive', 1),
#  ('"fred!"', 0),
#  ('"get', 0),
#  ('"ghost', 0),
#  ('"go', 0),
#  ('"god', 2),
#  ('"good', 7),
#  ('"green', 0),
#  ('"guess!"', 0),
#  ('"ha,', 3),
#  ('"half-past!"', 0),
#  ('"hallo!"', 1),
#  ('"have', 3),
#  ('"he', 9),
#  ('"he\'s', 1),
#  ('"hear', 1),
#  ('"heaven', 0),
#  ('"here', 0),
#  ('"here\'s', 1),
#  ('"hide,', 0),
#  ('"hilli-ho!"', 0),
#  ('"his', 1),
#  ('"home,', 1),
#  ('"how', 5),
#  ('"humbug!"', 2),
#  ('"humbug."', 0),
#  ('"hurrah!', 0),
#  ('"i', 81),
#  ('"i!"', 1),
#  ('"i\'ll', 3),
#  ('"i\'m', 2),
#  ('"i--i', 0),
#  ('"if', 8),
#  ('"in', 4),
#  ('"indeed,', 0),
#  ('"is', 6),
#  ('"it', 11),
#  ('"it\'s', 14),
#  ('"jacob,"', 0),
#  ('"keep', 1),
#  ('"knew', 0),
#  ('"know', 0),
#  ('"last', 0),
#  ('"lead', 1),
#  ('"leave', 0),
#  ('"left', 0),
#  ('"let', 6),
#  ('"liberality,"', 0),
#  ('"long', 0),
#  ('"look', 1),
#  ('"lord', 0),
#  ('"man', 0),
#  ('"man,"', 0),
#  ('"mankind', 0),
#  ('"many', 0),
#  ('"men\'s', 0),
#  ('"mercy!"', 0),
#  ('"merry', 0),
#  ('"more', 1),
#  ('"mr.', 4),
#  ('"much', 0),
#  ('"much!"--marley\'s', 0),
#  ('"my', 10),
#  ('"nay,', 0),
#  ('"nephew!"', 0),
#  ('"never,', 0),
#  ('"never,"', 0),
#  ('"no', 5),
#  ('"no,', 6),
#  ('"no,"', 1),
#  ('"no.', 3),
#  ('"not', 5),
#  ('"nothing', 0),
#  ('"nothing!"', 0),
#  ('"nothing,"', 0),
#  ('"nothing.', 0),
#  ('"notwithstanding."', 0),
#  ('"now,', 0),
#  ('"nuts"', 0),
#  ('"often."', 0),
#  ('"oh!', 1),
#  ('"oh,', 2),
#  ('"old', 1),
#  ('"on', 2),
#  ('"one', 3),
#  ('"only', 0),
#  ('"or', 2),
#  ('"our', 0),
#  ('"past', 0),
#  ('"peter', 0),
#  ('"plenty', 0),
#  ('"pooh,', 0),
#  ('"poor', 0),
#  ('"putting', 0),
#  ('"quick!"', 0),
#  ('"remember', 0),
#  ('"remove', 1),
#  ('"rise!', 0),
#  ('"scrooge', 1),
#  ('"seasonable', 0),
#  ('"seven', 0),
#  ('"she', 0),
#  ('"show', 1),
#  ('"since', 0),
#  ('"sir', 0),
#  ('"sit', 0),
#  ('"slander', 0),
#  ('"slow!"', 0),
#  ('"small!"', 0),
#  ('"so', 1),
#  ('"somebody', 0),
#  ('"something', 0),
#  ('"something"', 0),
#  ('"something,', 0),
#  ('"spectre,"', 0),
#  ('"spirit!', 0),
#  ('"spirit!"', 4),
#  ('"spirit,"', 2),
#  ('"strange', 0),
#  ('"sunday!', 0),
#  ('"tell', 2),
#  ('"thank\'ee!"', 0),
#  ('"thank\'ee,"', 0),
#  ('"thank\'ee.', 0),
#  ('"that', 5),
#  ('"that\'s', 4),
#  ('"the', 9),
#  ('"there', 4),
#  ('"there\'s', 3),
#  ('"these', 0),
#  ('"they', 5),
#  ('"they\'re', 0),
#  ('"this', 3),
#  ('"three', 0),
#  ('"through', 0),
#  ('"to', 5),
#  ('"to-day!"', 0),
#  ('"to-night', 0),
#  ('"to-night!"', 0),
#  ('"touch', 0),
#  ('"true,"', 0),
#  ('"uncle!"', 0),
#  ('"under', 0),
#  ('"very', 1),
#  ('"walk-er!"', 0),
#  ('"was', 2),
#  ('"we', 2),
#  ('"we\'d', 0),
#  ('"well', 0),
#  ('"well!', 2),
#  ('"well!"', 1),
#  ('"well,', 0),
#  ('"what', 18),
#  ('"what!"', 0),
#  ('"what\'s', 1),
#  ('"what,', 0),
#  ('"when', 1),
#  ('"where', 0),
#  ('"who', 3),
#  ('"who\'s', 0),
#  ('"who,', 0),
#  ('"whose', 0),
#  ('"why', 7),
#  ('"why!', 0),
#  ('"why,', 8),
#  ('"why?"', 0),
#  ('"will', 0),
#  ('"without', 0),
#  ('"would', 1),
#  ('"wouldn\'t', 0),
#  ('"yes', 0),
#  ('"yes!"', 0),
#  ('"yes,', 1),
#  ('"yes,"', 0),
#  ('"yes.', 0),
#  ('"yes."', 0),
#  ('"yes;"', 0),
#  ('"yo', 1),
#  ('"you', 27),
#  ('"you\'ll', 0),
#  ('"you\'re', 1),
#  ('"your', 5),
#  ("'and", 0),
#  ("'change,", 1),
#  ("'em", 8),
#  ("'em,", 0),
#  ("'em--seven,", 0),
#  ("'for", 0),
#  ("'heartily", 0),
#  ("'i", 0),
#  ("'merry", 0),
#  ("'poor", 0),
#  ("'prentices,", 0),
#  ("'that's", 0),
#  ("'uncle", 0),
#  ('(a', 0),
#  ('(an', 0),
#  ('(as', 0),
#  ("(bob's", 0),
#  ('(for', 4),
#  ('(not', 0),
#  ('(ready', 0),
#  ('(scrooge', 0),
#  ('(surveying', 0),
#  ('(they', 0),
#  ('(which', 2),
#  ('--born', 0),
#  ('--he', 0),
#  ('--on,', 0),
#  ('1843.', 0),
#  ('a', 679),
#  ('a-week', 0),
#  ('abed', 0),
#  ('abels,', 0),
#  ('abject,', 0),
#  ('able', 1),
#  ('abode!', 0),
#  ('about', 47),
#  ('about,', 3),
#  ('above', 4),
#  ('above,', 1),
#  ('abrahams,', 0),
#  ('abroad', 1),
#  ('abstinence', 0),
#  ('abundance', 0),
#  ('abyss,', 0),
#  ('accommodate', 0),
#  ('accompanied', 2),
#  ('account', 0),
#  ('account,"', 0),
#  ('account.', 1),
#  ('accuracy,', 0),
#  ('accustomed', 1),
#  ('ache;', 0),
#  ('achieved', 0),
#  ('acquaintance.', 0),
#  ('acquainted', 0),
#  ('across', 3),
#  ('act', 1),
#  ('act.', 0),
#  ('acted', 0),
#  ('action', 0),
#  ('action,', 0),
#  ('active', 0),
#  ('adamant,', 0),
#  ('adapted', 0),
#  ('add', 0),
#  ('added', 1),
#  ('added,', 0),
#  ('address', 0),
#  ('addressed', 1),
#  ('addressed.', 0),
#  ('addressing', 0),
#  ('adjoining', 0),
#  ('adjusted', 1),
#  ('adjustment', 0),
#  ('administered', 0),
#  ('administrator,', 0),
#  ('admiration', 1),
#  ('admiration.', 0),
#  ('admit', 0),
#  ('admitted', 0),
#  ('advance', 0),
#  ('advanced', 2),
#  ('advantage', 0),
#  ('adventure', 0),
#  ('adversary,', 0),
#  ('affability!', 0),
#  ('affairs', 0),
#  ('affection!', 0),
#  ('affectionate', 0),
#  ('affects', 0),
#  ('afford', 0),
#  ('afforded', 0),
#  ('affront', 0),
#  ('afraid', 4),
#  ('afraid,', 1),
#  ('after', 22),
#  ('afternoon', 0),
#  ('afternoon!"', 2),
#  ('afternoon,', 1),
#  ('afternoon,"', 1),
#  ('afternoon.', 0),
#  ('afternoon."', 0),
#  ('afterwards', 0),
#  ('afterwards,', 1),
#  ('afterwards;', 0),
#  ('again', 11),
#  ('again!"', 0),
#  ('again,', 12),
#  ('again,"', 0),
#  ('again.', 16),
#  ('again;', 4),
#  ('against', 9),
#  ('age,', 0),
#  ('age;', 1),
#  ('ages', 0),
#  ('agility.', 0),
#  ('agitated', 1),
#  ('agitation.', 0),
#  ('ago,', 3),
#  ('ago.', 0),
#  ('agonised,', 0),
#  ('agony,', 0),
#  ('agreeable', 0),
#  ('ah!', 1),
#  ('ah,', 1),
#  ('air', 7),
#  ('air,', 2),
#  ('air.', 2),
#  ('air;', 2),
#  ('alarm!', 0),
#  ('alarming', 1),
#  ('alas', 0),
#  ('aldermen,', 0),
#  ('ali', 1),
#  ('alike.', 0),
#  ('alive', 1),
#  ('alive,', 2),
#  ('all', 111),
#  ('all,', 6),
#  ('all,"', 1),
#  ('all.', 5),
#  ('all."', 1),
#  ('alleys', 0),
#  ('allow', 1),
#  ('allowed', 1),
#  ('almonds', 0),
#  ('almost', 2),
#  ('almshouse,', 0),
#  ('alone', 6),
#  ('alone,', 2),
#  ('alone,"', 0),
#  ('alone--too', 0),
#  ('alone.', 0),
#  ('along', 6),
#  ('along,', 0),
#  ('along.', 0),
#  ('alphabet.', 0),
#  ('already', 1),
#  ('already--', 0),
#  ('also', 5),
#  ('also,', 0),
#  ('altar', 0),
#  ('alteration', 1),
#  ('altered', 1),
#  ('although', 5),
#  ('altogether', 0),
#  ('always', 15),
#  ('always.', 0),
#  ('am', 39),
#  ('am!"', 0),
#  ('am.', 0),
#  ('amazed,', 0),
#  ('amends', 1),
#  ('among', 16),
#  ('amongst', 0),
#  ('ample', 0),
#  ('an', 76),
#  ("an't", 3),
#  ('ancestors', 0),
#  ('ancient', 4),
#  ('and', 1007),
#  ('and,', 8),
#  ('angel,', 0),
#  ('angelic', 0),
#  ('angels', 0),
#  ('angry', 3),
#  ('angry,', 0),
#  ('animal', 0),
#  ('animal,', 3),
#  ('ankle', 0),
#  ('ankle,', 0),
#  ('announced', 0),
#  ('announcement', 0),
#  ('anonymous?"', 0),
#  ('another', 28),
#  ('another,', 2),
#  ('another.', 1),
#  ('another;', 0),
#  ('answer', 4),
#  ('answer,', 0),
#  ('answer.', 1),
#  ('answered', 4),
#  ('answered,', 2),
#  ('answered.', 0),
#  ('answering', 0),
#  ('antique', 0),
#  ('anxious', 1),
#  ('anxiously', 0),
#  ('any', 39),
#  ('anybody', 4),
#  ('anybody,', 0),
#  ('anyhow', 0),
#  ('anything', 10),
#  ('anything,', 2),
#  ('anything--could', 0),
#  ('anything.', 1),
#  ('anything;', 0),
#  ('anyway,', 0),
#  ('anywhere.', 0),
#  ('apart', 1),
#  ('apoplectic', 0),
#  ('apostles', 0),
#  ('appalled.', 0),
#  ('appalling', 0),
#  ('apparel,', 0),
#  ('apparently', 0),
#  ('apparition', 0),
#  ('apparition,', 0),
#  ('appealing', 0),
#  ('appear', 0),
#  ('appearance', 0),
#  ('appearance,', 0),
#  ('appearances,', 0),
#  ('appeared', 11),
#  ('appeared,', 0),
#  ('appeared.', 0),
#  ('appearing', 1),
#  ('appetite', 0),
#  ('appetite.', 0),
#  ('applauded.', 0),
#  ('apple-sauce', 0),
#  ('apple-sauce;', 0),
#  ('apples', 0),
#  ('apples,', 1),
#  ('applied', 0),
#  ('apply', 2),
#  ('appraised', 0),
#  ('apprehensive', 0),
#  ('apprentice', 0),
#  ('apprenticed', 0),
#  ('apprentices,', 0),
#  ('approach,', 0),
#  ('approach.', 0),
#  ('approached', 0),
#  ('approached.', 0),
#  ('appropriate.', 0),
#  ('approving', 0),
#  ('aprons', 0),
#  ('archways,', 0),
#  ('are', 44),
#  ('are!"', 1),
#  ('are,', 0),
#  ('are,"', 0),
#  ('are.', 1),
#  ('are?"', 0),
#  ('arm', 1),
#  ("arm's", 0),
#  ('arm,', 1),
#  ('arm.', 2),
#  ('arms', 1),
#  ('arms,', 2),
#  ('arms.', 0),
#  ('aromatic', 0),
#  ('arose', 0),
#  ('array);', 0),
#  ('arrival,', 0),
#  ('arrived.', 0),
#  ('artful', 0),
#  ('artifice.', 0),
#  ('artificial', 0),
#  ('as', 221),
#  ('ashamed,', 0),
#  ('aside', 0),
#  ('aside,', 0),
#  ('aside;', 0),
#  ('ask', 3),
#  ('ask,"', 0),
#  ('asked', 20),
#  ('asleep', 0),
#  ('asleep,', 0),
#  ('aspirations', 0),
#  ('ass', 0),
#  ('ass,', 0),
#  ('assembled', 1),
#  ('assembling;', 0),
#  ('assign,', 0),
#  ('assigned;', 0),
#  ('assist', 1),
#  ('assisted', 0),
#  ('associated', 0),
#  ('assure', 3),
#  ('assured', 0),
#  ('astonish', 0),
#  ('astonished', 0),
#  ('astonishment', 0),
#  ('astonishment,', 1),
#  ('at', 146),
#  ('at,', 0),
#  ('at:', 0),
#  ('at;', 0),
#  ('ate', 0),
#  ('atmosphere', 1),
#  ('atom', 0),
#  ('atoms,', 0),
#  ('attach', 0),
#  ('attached', 1),
#  ('attended', 0),
#  ('attention,', 1),
#  ('attentively', 0),
#  ('attire.', 0),
#  ('attired,', 0),
#  ('attitude', 0),
#  ('attitude,', 1),
#  ('attract', 0),
#  ('attractive', 0),
#  ('aught', 0),
#  ('aunts,', 0),
#  ('authority', 0),
#  ('avarice,', 0),
#  ('avarice.', 0),
#  ('avoid', 0),
#  ('awake', 0),
#  ('awaking', 0),
#  ('away', 9),
#  ('away!', 0),
#  ('away,', 6),
#  ('away.', 1),
#  ('away?"', 0),
#  ('awful', 1),
#  ('awful,', 0),
#  ('awkwardly,', 0),
#  ('awoke,', 0),
#  ('awoke.', 0),
#  ('axe', 0),
#  ('baba!', 0),
#  ('baba!"', 0),
#  ('baby', 2),
#  ('baby.', 1),
#  ('bachelor', 0),
#  ('back', 15),
#  ('back,', 5),
#  ('back-payments', 0),
#  ('back-shop.', 0),
#  ('back-yard,', 0),
#  ('back.', 2),
#  ('backs,', 0),
#  ('backward', 0),
#  ('bad', 3),
#  ('bad,', 0),
#  ('bad?"--to', 0),
#  ('bade', 2),
#  ('badly', 0),
#  ('bag', 0),
#  ('bags', 0),
#  ("baker's", 2),
#  ("baker's),", 0),
#  ('baker.', 0),
#  ('bakers', 0),
#  ("bakers'", 0),
#  ('baking', 0),
#  ('balancing', 0),
#  ('baleful', 0),
#  ('ball', 0),
#  ('ball-room,', 0),
#  ('balustrades:', 0),
#  ('bandage', 0),
#  ('bandage.', 0),
#  ('bang.', 0),
#  ("banker's-book,", 0),
#  ('bare,', 2),
#  ('bare.', 0),
#  ('bare;', 0),
#  ('bared', 0),
#  ('barely', 0),
#  ('bareness', 0),
#  ('barer', 0),
#  ('bargain', 0),
#  ('bargain.', 0),
#  ('barred', 0),
#  ('barrels', 0),
#  ('barren', 0),
#  ('base,', 0),
#  ('basin', 0),
#  ('baskets', 1),
#  ('basking', 0),
#  ('bass', 0),
#  ('battled', 0),
#  ('be', 125),
#  ('be!"', 0),
#  ('be,', 6),
#  ('be,"', 0),
#  ('be.', 6),
#  ('be:', 0),
#  ('beaming', 1),
#  ('bear', 4),
#  ('bear.', 0),
#  ('bear?"', 0),
#  ('bearers', 0),
#  ('bearing', 0),
#  ('beat', 3),
#  ('beaten', 0),
#  ('beating', 0),
#  ('beautiful', 0),
#  ('beautiful.', 0),
#  ('became', 9),
#  ('because', 5),
#  ('beckoned', 0),
#  ('become', 2),
#  ('becoming', 1),
#  ('bed', 6),
#  ('bed,', 6),
#  ('bed-curtains', 0),
#  ('bed.', 4),
#  ('bed:', 1),
#  ('bed;', 1),
#  ('bed?"', 0),
#  ('bedight', 0),
#  ('bedlam."', 0),
#  ('bedpost', 0),
#  ('bedpost.', 0),
#  ('bedroom,', 0),
#  ('bedroom.', 0),
#  ('beds,', 0),
#  ('beds;', 0),
#  ('beef,', 0),
#  ('beef.', 0),
#  ('been', 58),
#  ('been,', 4),
#  ('been,"', 1),
#  ('been;', 0),
#  ('beer.', 0),
#  ('beetling', 0),
#  ('before', 41),
#  ('before!"', 0),
#  ('before,', 7),
#  ('before--though', 0),
#  ('before.', 2),
#  ('before;', 1),
#  ('beforehand', 0),
#  ('began', 6),
#  ('began,', 0),
#  ('beggars', 1),
#  ('beggars,', 0),
#  ('begged', 2),
#  ('begin', 1),
#  ('beginning', 0),
#  ('begins', 0),
#  ('beguiled', 0),
#  ('begun', 0),
#  ('begun,', 0),
#  ('behave?"', 0),
#  ('beheld', 1),
#  ('behind', 14),
#  ('behind,', 0),
#  ('behind.', 0),
#  ('behindhand,', 0),
#  ('behold', 0),
#  ('behold,', 0),
#  ('being', 34),
#  ('being,', 0),
#  ('beings', 0),
#  ('belief;', 0),
#  ('believe', 11),
#  ('believe,"', 0),
#  ('believe.', 0),
#  ('believe."', 1),
#  ('believe;', 0),
#  ('believe?"', 0),
#  ('believed', 2),
#  ('belinda', 1),
#  ('belinda,', 0),
#  ('bell', 10),
#  ('bell,', 2),
#  ('bell.', 0),
#  ('bells', 1),
#  ('bells.', 0),
#  ('belonged', 0),
#  ('belonging', 2),
#  ('below', 4),
#  ('below,', 2),
#  ('below;', 1),
#  ('belshazzars,', 0),
#  ('belt', 0),
#  ('belt,', 1),
#  ('bending', 0),
#  ('beneath', 5),
#  ('benefit', 0),
#  ('benevolence', 0),
#  ('benevolence,', 0),
#  ('benevolence;', 0),
#  ('bent', 1),
#  ('bereft,', 0),
#  ('berries', 1),
#  ('berries,', 0),
#  ('beseech', 0),
#  ('beseeching', 0),
#  ('beside', 9),
#  ('besides--excuse', 0),
#  ('besought', 0),
#  ('best', 4),
#  ('best,"', 0),
#  ('best-parlour', 0),
#  ('bestow', 1),
#  ('bestowed', 0),
#  ('better', 11),
#  ('better,', 0),
#  ('better.', 0),
#  ('between', 7),
#  ('beware', 1),
#  ('bewildering', 0),
#  ('beyond', 8),
#  ('beyond,', 0),
#  ('bide', 0),
#  ('biffins,', 0),
#  ('big', 1),
#  ('bigotry,', 0),
#  ('bilious.', 0),
#  ('bills', 0),
#  ('bird.', 0),
#  ('birds;', 0),
#  ('bishop,', 0),
#  ('bit', 2),
#  ('biting', 1),
#  ('bitter', 0),
#  ('bitterer', 0),
#  ('black', 5),
#  ('black,', 1),
#  ('black.', 0),
#  ('blacker,', 0),
#  ('blame', 0),
#  ('blank', 1),
#  ('blankets,', 0),
#  ('blankets?"', 0),
#  ('blaze', 3),
#  ('blazing', 1),
#  ('bleak', 0),
#  ('bleak,', 1),
#  ('blended', 0),
#  ('bless', 13),
#  ('blessed', 1),
#  ('blessing,', 0),
#  ('blessings', 0),
#  ('blest', 0),
#  ('blew', 1),
#  ('blind', 3),
#  ('blind-man', 0),
#  ("blind-man's", 1),
#  ('blindfold."', 0),
#  ("blindman's-buff.", 0),
#  ('blithe', 1),
#  ('blithest', 0),
#  ('block', 0),
#  ('blood', 2),
#  ('bloodthirsty', 0),
#  ('bloom', 0),
#  ('blooming', 0),
#  ('blot', 0),
#  ('blotch', 0),
#  ('blue;', 0),
#  ('blunt', 0),
#  ('blush;', 0),
#  ('blushed', 1),
#  ('board', 0),
#  ('board,', 1),
#  ('boarding-school,', 0),
#  ('boast', 0),
#  ('boasted', 0),
#  ('bob', 23),
#  ('bob!', 0),
#  ('bob!"', 0),
#  ("bob's", 2),
#  ('bob,', 13),
#  ('bob.', 6),
#  ('bob;', 0),
#  ('body', 3),
#  ('body.', 0),
#  ('body:', 0),
#  ('boiled', 1),
#  ('boiled,', 1),
#  ('boisterous', 0),
#  ('bold', 3),
#  ('boldly,', 0),
#  ('bolts', 0),
#  ('bone', 0),
#  ('bones', 1),
#  ('bones,', 0),
#  ('bones.', 1),
#  ('bonnet', 0),
#  ('book', 0),
#  ('book,', 0),
#  ('book.', 0),
#  ('books', 1),
#  ('booming', 0),
#  ('boots.', 1),
#  ('boots;', 0),
#  ('bordered', 0),
#  ('bore', 3),
#  ('born', 1),
#  ('borne', 1),
#  ('borough,', 0),
#  ('both', 4),
#  ('both,', 0),
#  ('bothered', 0),
#  ('bottle', 0),
#  ('bottles,', 0),
#  ('bottom', 0),
#  ('boughs', 0),
#  ('bought.', 0),
#  ('bound', 3),
#  ('bound,', 0),
#  ('bound?"', 0),
#  ('bounds', 0),
#  ('bow', 0),
#  ('bow,', 0),
#  ('bowed', 0),
#  ('bowels', 0),
#  ('bowels,', 0),
#  ('bowl', 0),
#  ('bowl,', 0),
#  ('bowls', 0),
#  ('box,', 0),
#  ('boxes,', 0),
#  ('boy', 10),
#  ('boy!', 1),
#  ('boy!"', 3),
#  ('boy,', 3),
#  ('boy,"', 0),
#  ('boy--and', 0),
#  ('boy.', 6),
#  ('boys', 5),
#  ('boys!"', 0),
#  ('boys,', 0),
#  ('braided', 0),
#  ('bran-new', 0),
#  ('branch', 0),
#  ('branched', 0),
#  ('brandy,', 0),
#  ('brave', 1),
#  ('brave,', 0),
#  ('brawn,', 1),
#  ('brazier,', 0),
#  ('breach', 0),
#  ('breadth', 0),
#  ('break', 0),
#  ('breast', 0),
#  ('breast!', 0),
#  ('breast,', 0),
#  ('breast;', 0),
#  ('breasts,', 0),
#  ('breath', 5),
#  ('breath,', 0),
#  ('breath;', 0),
#  ('breathless', 1),
#  ('bred', 1),
#  ('breeches', 0),
#  ('breezy', 0),
#  ('brewing', 0),
#  ('brick,', 0),
#  ('bricks,', 0),
#  ('bridge,', 0),
#  ('bridle', 0),
#  ('brief', 1),
#  ('brief,"', 0),
#  ('briefly,', 0),
#  ('brigands', 0),
#  ('bright', 6),
#  ('bright,', 1),
#  ('bright;', 0),
#  ('brighter;', 0),
#  ('brightest', 0),
#  ('brightness', 2),
#  ('brilliant', 0),
#  ('brimful', 0),
#  ('bring', 5),
#  ('brings', 0),
#  ('brisk', 1),
#  ('briskly', 0),
#  ('briskly,', 0),
#  ('bristling,', 0),
#  ('britain', 0),
#  ('broad', 1),
#  ('broad-girthed', 0),
#  ('broadwise,', 0),
#  ('broke', 2),
#  ('broke.', 0),
#  ('broken', 2),
#  ('broken,', 0),
#  ('brooch', 0),
#  ('brood', 0),
#  ('brood,', 0),
#  ('brother', 0),
#  ('brother!"', 0),
#  ("brother's", 0),
#  ('brother,', 1),
#  ('brother."', 0),
#  ('brothers', 1),
#  ('brothers,', 1),
#  ('brought', 5),
#  ('brow', 0),
#  ('brow!"', 0),
#  ('brow.', 0),
#  ('brown', 1),
#  ('brown,', 0),
#  ('brown-faced,', 0),
#  ('brown-paper', 0),
#  ('brushed,', 0),
#  ('bubbling', 0),
#  ('buck!"', 0),
#  ('buff', 0),
#  ('buff.', 0),
#  ('building', 0),
#  ('building.', 0),
#  ('built', 1),
#  ('bull,', 0),
#  ('bumping', 0),
#  ('bunches', 0),
#  ('bundle', 1),
#  ('bundle,', 2),
#  ('burdensome;', 0),
#  ('burial', 0),
#  ('burial-place', 0),
#  ('buried', 2),
#  ('burning', 0),
#  ('burnt', 0),
#  ('burst', 1),
#  ('burying;', 0),
#  ('business', 10),
#  ('business!"', 0),
#  ('business,', 1),
#  ('business,"', 0),
#  ('business-like', 0),
#  ('business.', 2),
#  ('business:', 0),
#  ('business;', 1),
#  ('bustle', 0),
#  ('busy', 3),
#  ('busy,', 0),
#  ('but', 159),
#  ('but,', 1),
#  ('butlers', 0),
#  ('butter-boats,', 0),
#  ('button', 0),
#  ('buttoning', 0),
#  ('buttons', 0),
#  ('buy', 4),
#  ('by', 116),
#  ('by,', 2),
#  ('by-and-bye', 0),
#  ('by.', 0),
#  ('bye!"', 0),
#  ('bye,', 1),
#  ('bye-streets,', 0),
#  ('bye-ways,', 0),
#  ('bygone', 0),
#  ('c.', 0),
#  ('cab,', 0),
#  ('cab."', 0),
#  ...]

# %%
 sorted(count.items(), key=lambda x: x[1])
# Out:
# [('keenly.', 0),
#  ('wits.', 0),
#  ('man!', 0),
#  ('repeat,', 0),
#  ('main', 0),
#  ('sprung', 0),
#  ('limits', 0),
#  ('residence', 0),
#  ('"through', 0),
#  ('meeting,', 0),
#  ('die?', 0),
#  ('seat,"', 0),
#  ('shine.', 0),
#  ('sea?', 0),
#  ("'uncle", 0),
#  ('repassed;', 0),
#  ('grass', 0),
#  ('doubt!"', 0),
#  ('linked', 0),
#  ('stagger.', 0),
#  ('lands,', 0),
#  ('island.', 0),
#  ('"our', 0),
#  ('implored', 0),
#  ('you:', 0),
#  ('ha!--that', 0),
#  ('saturdays', 0),
#  ('trial', 0),
#  ('(not', 0),
#  ('clocks', 0),
#  ('quoted', 0),
#  ('passengers', 0),
#  ('twine', 0),
#  ('sad', 0),
#  ('lashes', 0),
#  ('coal-scuttle', 0),
#  ('counting-house.', 0),
#  ('bending', 0),
#  ('using', 0),
#  ('never."', 0),
#  ('supposed', 0),
#  ('"wouldn\'t', 0),
#  ('half-a-crown."', 0),
#  ('laid,', 0),
#  ('red-faced', 0),
#  ('pursue', 0),
#  ('provision', 0),
#  ('intervention.', 0),
#  ('boy,"', 0),
#  ('angelic', 0),
#  ('hurry', 0),
#  ('grinning.', 0),
#  ('deuce', 0),
#  ('couples', 0),
#  ('gain,', 0),
#  ('comforter,', 0),
#  ('bachelor', 0),
#  ('parting.', 0),
#  ('poplar,', 0),
#  ('point,', 0),
#  ('chance!', 0),
#  ('fought', 0),
#  ('humility', 0),
#  ('ball', 0),
#  ('cracking', 0),
#  ('array);', 0),
#  ('plumping', 0),
#  ('him--if', 0),
#  ('"thank\'ee.', 0),
#  ('mysterious', 0),
#  ('chief', 0),
#  ('sums', 0),
#  ('vain,', 0),
#  ('industry', 0),
#  ('trade.', 0),
#  ('festive', 0),
#  ('"bob"', 0),
#  ('washing-stand', 0),
#  ('rose.', 0),
#  ('away!', 0),
#  ('letting', 0),
#  ('reply', 0),
#  ('cat,', 0),
#  ('be!"', 0),
#  ('great-coat', 0),
#  ('congenial', 0),
#  ('utmost,', 0),
#  ('enter.', 0),
#  ('"knew', 0),
#  ('upon.', 0),
#  ('stomach-aches.', 0),
#  ('round;', 0),
#  ('hey?"', 0),
#  ('unmoved', 0),
#  ("son's", 0),
#  ('ponderous', 0),
#  ('minute', 0),
#  ('ghost!"', 0),
#  ('licence', 0),
#  ('burial-place', 0),
#  ('tried,', 0),
#  ('brow.', 0),
#  ('affection!', 0),
#  ('"nay,', 0),
#  ('disclaimed', 0),
#  ('eagerness,', 0),
#  ('"plenty', 0),
#  ('clutching,', 0),
#  ('halloo!"', 0),
#  ('me--i', 0),
#  ('kin,', 0),
#  ('place."', 0),
#  ('undermine', 0),
#  ('coil', 0),
#  ('matron,', 0),
#  ('ruddy,', 0),
#  ('therefore,', 0),
#  ('looks;', 0),
#  ('buck!"', 0),
#  ('blest', 0),
#  ('luxurious', 0),
#  ('miscellaneous', 0),
#  ('competent', 0),
#  ('race', 0),
#  ('resorting', 0),
#  ('scraping,', 0),
#  ('buttoning', 0),
#  ('"because,"', 0),
#  ('knees!"', 0),
#  ('talking', 0),
#  ('matched.', 0),
#  ('unless', 0),
#  ('asleep,', 0),
#  ('besought', 0),
#  ('woods,', 0),
#  ('worthless', 0),
#  ('hallo!"', 0),
#  ('regale', 0),
#  ('calling,', 0),
#  ('sword', 0),
#  ('singer', 0),
#  ('breach', 0),
#  ('speech,', 0),
#  ('new-born', 0),
#  ('lateness', 0),
#  ('cooks', 0),
#  ('fate.', 0),
#  ('weakness', 0),
#  ('names.', 0),
#  ("hamlet's", 0),
#  ('gentlemen!"', 0),
#  ('knock.', 0),
#  ('apples', 0),
#  ('opinion.', 0),
#  ('glow;', 0),
#  ('accuracy,', 0),
#  ('kick', 0),
#  ('post,', 0),
#  ('repeated,', 0),
#  ('snowing', 0),
#  ('boasted', 0),
#  ('case;', 0),
#  ('abyss,', 0),
#  ('remembered,', 0),
#  ('truly!', 0),
#  ('"notwithstanding."', 0),
#  ('glazed', 0),
#  ('visited', 0),
#  ('fezziwigs,', 0),
#  ('filberts,', 0),
#  ('on."', 0),
#  ('cesspools,', 0),
#  ('suffers', 0),
#  ('contagious', 0),
#  ('present;', 0),
#  ('beetling', 0),
#  ('undoubted', 0),
#  ('ye!', 0),
#  ("he'll", 0),
#  ('dream', 0),
#  ('knowledge', 0),
#  ('flannel', 0),
#  ('favour,', 0),
#  ('preparations', 0),
#  ('charitable,', 0),
#  ('conducive', 0),
#  ('paths', 0),
#  ('visited,', 0),
#  ('sin.', 0),
#  ('waistcoat', 0),
#  ('grateful,', 0),
#  ('seals;', 0),
#  ('ivy,', 0),
#  ("'heartily", 0),
#  ('be,"', 0),
#  ('think.', 0),
#  ('dirge;', 0),
#  ('shrouded', 0),
#  ('crime,', 0),
#  ('glimpse', 0),
#  ('supplication.', 0),
#  ('eagerness;', 0),
#  ('"dick', 0),
#  ('by.', 0),
#  ('then!', 0),
#  ('straight,', 0),
#  ('future--into', 0),
#  ('on.', 0),
#  ('deeds,', 0),
#  ('gentleman!', 0),
#  ('lamplight.', 0),
#  ("people's.", 0),
#  ('demanded', 0),
#  ('pleasantly', 0),
#  ('archways,', 0),
#  ('screw,"', 0),
#  ('grove;', 0),
#  ('cap', 0),
#  ('condensed', 0),
#  ('mused', 0),
#  ('caverns', 0),
#  ('hummed', 0),
#  ('hark!', 0),
#  ('credentials.', 0),
#  ('goblins,', 0),
#  ('business!"', 0),
#  ('creature', 0),
#  ('peck', 0),
#  ('transports', 0),
#  ('cooking,', 0),
#  ('tears,', 0),
#  ('marley?"', 0),
#  ('coal-box', 0),
#  ('list.', 0),
#  ('fearful', 0),
#  ('"yes;"', 0),
#  ('occurred', 0),
#  ('faltering', 0),
#  ('palpable', 0),
#  ('cat', 0),
#  ('likeness', 0),
#  ('infant,', 0),
#  ('lose', 0),
#  ('foretold', 0),
#  ('retired', 0),
#  ('defiance', 0),
#  ('forced', 0),
#  ('fined', 0),
#  ('image;', 0),
#  ('chosen!"', 0),
#  ('spectre,', 0),
#  ('noticed', 0),
#  ('explanation', 0),
#  ('lane,', 0),
#  ('laundress', 0),
#  ('darker', 0),
#  ('hail,', 0),
#  ('much,"', 0),
#  ('clearly,', 0),
#  ('principle', 0),
#  ('i.', 0),
#  ('entered.', 0),
#  ('takes', 0),
#  ('clock,', 0),
#  ('pocket', 0),
#  ('bad?"--to', 0),
#  ('nine.', 0),
#  ('groped', 0),
#  ('fragment', 0),
#  ('lurked,', 0),
#  ('begun,', 0),
#  ('water-proof;', 0),
#  ('leading', 0),
#  ('panelling,', 0),
#  ('care.', 0),
#  ('bottle', 0),
#  ('modest', 0),
#  ('raisins', 0),
#  ('"why!', 0),
#  ('degree', 0),
#  ('like.', 0),
#  ('fictitious', 0),
#  ('delightful', 0),
#  ('dunstan', 0),
#  ('loud;', 0),
#  ('fortunes;', 0),
#  ('selfishness', 0),
#  ('funeral,', 0),
#  ('winding', 0),
#  ('committed', 0),
#  ('unconscious', 0),
#  ('haste,', 0),
#  ('child:', 0),
#  ('derived', 0),
#  ('sudden,', 0),
#  ('apparition,', 0),
#  ('house!', 0),
#  ('fur.', 0),
#  ('wander', 0),
#  ('quarrel,', 0),
#  ('decayed.', 0),
#  ('weigh', 0),
#  ('property,', 0),
#  ('embarrassing', 0),
#  ('send', 0),
#  ('everybody!', 0),
#  ('surprised-looking,', 0),
#  ('dragged', 0),
#  ('supposition', 0),
#  ('kerchief', 0),
#  ('aside;', 0),
#  ("banker's-book,", 0),
#  ('business-like', 0),
#  ('good;', 0),
#  ('retentive', 0),
#  ('devils', 0),
#  ('brooch', 0),
#  ('occupies', 0),
#  ('froze', 0),
#  ('bridge,', 0),
#  ('veneration', 0),
#  ('plum-puddings,', 0),
#  ('associated', 0),
#  ('badly', 0),
#  ('doubt,', 0),
#  ('ill,', 0),
#  ('abed', 0),
#  ('sharper', 0),
#  ('catching', 0),
#  ('named', 0),
#  ('jiffy;', 0),
#  ('glided', 0),
#  ('defy', 0),
#  ('gush', 0),
#  ('dining', 0),
#  ('time--of', 0),
#  ('boots;', 0),
#  ('strutted', 0),
#  ('yours', 0),
#  ('relate.', 0),
#  ('motionless.', 0),
#  ('line', 0),
#  ('sugar-tongs,', 0),
#  ('"will', 0),
#  ('death-cold', 0),
#  ("doll's", 0),
#  ('dust!"', 0),
#  ('pencil-case,', 0),
#  ('down;', 0),
#  ('started!', 0),
#  ('beaten', 0),
#  ('strait-waistcoat.', 0),
#  ('place!', 0),
#  ('nowhere', 0),
#  ('assured', 0),
#  ('voice:', 0),
#  ('spirits."', 0),
#  ('resistance', 0),
#  ('dears.', 0),
#  ('i!', 0),
#  ('attire.', 0),
#  ('ruthlessly.', 0),
#  ('speak;', 0),
#  ('bared', 0),
#  ('hurrah!', 0),
#  ('dwellings,', 0),
#  ('subject.', 0),
#  ('condition', 0),
#  ('outpouring,', 0),
#  ('seven,', 0),
#  ('sealing-wax.', 0),
#  ('kindness', 0),
#  ('up,"', 0),
#  ('pyramids;', 0),
#  ('warmth.', 0),
#  ('doings', 0),
#  ('stingy,', 0),
#  ('shaped', 0),
#  ('change--not', 0),
#  ('bearers', 0),
#  ('say!--if', 0),
#  ('congealed,', 0),
#  ('part.', 0),
#  ('finds', 0),
#  ('undergoing', 0),
#  ('still."', 0),
#  ('aspirations', 0),
#  ('glisten,', 0),
#  ('boughs', 0),
#  ('noble', 0),
#  ('broad-girthed', 0),
#  ('briskly,', 0),
#  ('hope,', 0),
#  ('broke.', 0),
#  ('this!', 0),
#  ('laundress.', 0),
#  ("arm's", 0),
#  ('files,', 0),
#  ('praise,', 0),
#  ('heeded', 0),
#  ('roast', 0),
#  ('come.', 0),
#  ('seldom', 0),
#  ("mayor's", 0),
#  ('scrooge."', 0),
#  ('garden-sweep:', 0),
#  ('along.', 0),
#  ('peculiar', 0),
#  ('to.', 0),
#  ("other's", 0),
#  ('escaping', 0),
#  ('foreshadow', 0),
#  ('behold,', 0),
#  ('on--until,', 0),
#  ('salary,', 0),
#  ('rough', 0),
#  ('colder.', 0),
#  ('far,', 0),
#  ('interesting', 0),
#  ('carts,', 0),
#  ('shaggy', 0),
#  ('wish;', 0),
#  ('town.', 0),
#  ('"came', 0),
#  ('wretched,', 0),
#  ('success', 0),
#  ('kith', 0),
#  ('thawed', 0),
#  ('counting-house--mark', 0),
#  ('waxy', 0),
#  ('showing', 0),
#  ('discuss', 0),
#  ('peter;"', 0),
#  ('lock,', 0),
#  ('frost,', 0),
#  ('ready;', 0),
#  ('torch?"', 0),
#  ('skin.', 0),
#  ('effort', 0),
#  ('rub', 0),
#  ('miracle', 0),
#  ('white;', 0),
#  ('know!', 0),
#  ('wind,"', 0),
#  ('shouting', 0),
#  ('bells.', 0),
#  ('places--four,', 0),
#  ('had,"', 0),
#  ('miserable.', 0),
#  ('bedroom.', 0),
#  ('similar', 0),
#  ('"strange', 0),
#  ('impropriety,', 0),
#  ('forbearance,', 0),
#  ('sow', 0),
#  ('withal:', 0),
#  ('consent,', 0),
#  ('again,"', 0),
#  ('tree;', 0),
#  ('coolly.', 0),
#  ('sobbing', 0),
#  ('shuddering', 0),
#  ('group,', 0),
#  ('item', 0),
#  ('foremost', 0),
#  ('bones,', 0),
#  ('account,"', 0),
#  ('lighthouse.', 0),
#  ('statues', 0),
#  ('feather,', 0),
#  ('pommel', 0),
#  ('year,"', 0),
#  ('heart;', 0),
#  ('bargain', 0),
#  ('wisest', 0),
#  ('dining-room,', 0),
#  ('longer!"', 0),
#  ('devote', 0),
#  ('degrees', 0),
#  ('sight.', 0),
#  ('icicle', 0),
#  ('charles', 0),
#  ('rang', 0),
#  ('source', 0),
#  ('truest', 0),
#  ('odours', 0),
#  ('extinguished', 0),
#  ('honoured', 0),
#  ('face!', 0),
#  ("poulterer's,", 0),
#  ('roared,', 0),
#  ('ministers,', 0),
#  ('himself;', 0),
#  ('brother."', 0),
#  ('announcement', 0),
#  ('parcels,', 0),
#  ('situation."', 0),
#  ('rough,', 0),
#  ('ecstasy.', 0),
#  ('atom', 0),
#  ('thoughts?', 0),
#  ('hoarding', 0),
#  ('frost.', 0),
#  ('breast', 0),
#  ('anyway,', 0),
#  ('life!"', 0),
#  ('that?"', 0),
#  ('prodigiously', 0),
#  ('moral', 0),
#  ('appearance', 0),
#  ('knife,', 0),
#  ('ungrateful', 0),
#  ('fred.', 0),
#  ('tavern;', 0),
#  ('inaudible', 0),
#  ('fair.', 0),
#  ('perfectly.', 0),
#  ('skimmed.', 0),
#  ('gate', 0),
#  ('eager,', 0),
#  ('here--the', 0),
#  ('upon,', 0),
#  ('second.', 0),
#  ('spirit,"', 0),
#  ('drowsiness;', 0),
#  ('practice', 0),
#  ('seem', 0),
#  ('apostles', 0),
#  ('included', 0),
#  ('struggled', 0),
#  ('yonder,"', 0),
#  ('finishes', 0),
#  ('heartiness.', 0),
#  ('overflowings', 0),
#  ('musical', 0),
#  ('pitch-and-toss', 0),
#  ('servant', 0),
#  ('pray!"', 0),
#  ('industry.', 0),
#  ("'prentices,", 0),
#  ('i?', 0),
#  ('unhappy', 0),
#  ('"ah!"', 0),
#  ('doom,', 0),
#  ('caked', 0),
#  ('emotions', 0),
#  ('stony', 0),
#  ('dress.', 0),
#  ('wildly,', 0),
#  ('goodly', 0),
#  ('order,"', 0),
#  ('sweet', 0),
#  ('attract', 0),
#  ('handful', 0),
#  ('gazed', 0),
#  ('snuffed', 0),
#  ('large.', 0),
#  ('low-browed,', 0),
#  ('withdrawing', 0),
#  ('skirts.', 0),
#  ('must.', 0),
#  ('hard,', 0),
#  ('"well,', 0),
#  ('ray', 0),
#  ('pile', 0),
#  ('sparkling', 0),
#  ('cloth,', 0),
#  ('goose--a', 0),
#  ('rapidity', 0),
#  ('affectionate', 0),
#  ('fancied', 0),
#  ('sharpest', 0),
#  ('wish,', 0),
#  ('incredible', 0),
#  ('life,"', 0),
#  ('front', 0),
#  ('equal', 0),
#  ('passed.', 0),
#  ('waking', 0),
#  ('thunder.', 0),
#  ('gnawing', 0),
#  ('"never,', 0),
#  ('instalments', 0),
#  ('believe,"', 0),
#  ('excitement.', 0),
#  ('day\'s,"', 0),
#  ('ominous', 0),
#  ('deep,', 0),
#  ('past?"', 0),
#  ('barer', 0),
#  ('result', 0),
#  ('awful,', 0),
#  ('feel,', 0),
#  ('agitation.', 0),
#  ('answering', 0),
#  ('menacing.', 0),
#  ("cratchit,'", 0),
#  ('coats,', 0),
#  ('steady,', 0),
#  ('terrified', 0),
#  ('back-yard,', 0),
#  ('fortune,"', 0),
#  ('ghosts', 0),
#  ('wept', 0),
#  ('obscure', 0),
#  ('baker.', 0),
#  ('avarice,', 0),
#  ('do!"', 0),
#  ('mouth', 0),
#  ('ceased,', 0),
#  ('doors', 0),
#  ('lads,', 0),
#  ('belshazzars,', 0),
#  ('stirring,', 0),
#  ('sprigs', 0),
#  ('daughters;', 0),
#  ('recoiled', 0),
#  ('if,', 0),
#  ('population.', 0),
#  ('reeked', 0),
#  ('backs,', 0),
#  ('negative', 0),
#  ('water,', 0),
#  ('clutching', 0),
#  ('rust.', 0),
#  ('pounds,', 0),
#  ('"nothing', 0),
#  ('undergone', 0),
#  ('twelve,', 0),
#  ('friends,', 0),
#  ('munifi--"', 0),
#  ('terror;', 0),
#  ('"bear', 0),
#  ('retire,', 0),
#  ('underdone', 0),
#  ('now!"', 0),
#  ('ship.', 0),
#  ('engrosses', 0),
#  ('besides--excuse', 0),
#  ('gracefully', 0),
#  ('smell,', 0),
#  ('clap', 0),
#  ('heap', 0),
#  ('sun,', 0),
#  ('wanton', 0),
#  ('anything--could', 0),
#  ('poured', 0),
#  ('"answer', 0),
#  ('effect.', 0),
#  ('marley."', 0),
#  ('he.', 0),
#  ('picture', 0),
#  ('papers', 0),
#  ('swept', 0),
#  ('crushed', 0),
#  ('"leave', 0),
#  ('name;', 0),
#  ('struggling,', 0),
#  ('tremendously', 0),
#  ('written', 0),
#  ('dead!', 0),
#  ('answer,', 0),
#  ('cautiously', 0),
#  ('aprons', 0),
#  ('body:', 0),
#  ('ring', 0),
#  ('topper,', 0),
#  ("'merry", 0),
#  ('strolled', 0),
#  ('affairs', 0),
#  ('grog;', 0),
#  ('linger', 0),
#  ('"bonneted"', 0),
#  ('growl.', 0),
#  ('creek!', 0),
#  ('farmers.', 0),
#  ('still!"', 0),
#  ('"yes!"', 0),
#  ('undigested', 0),
#  ('forbid!"', 0),
#  ('consequences', 0),
#  ('slunk', 0),
#  ('feet;', 0),
#  ('straggling', 0),
#  ('love!"', 0),
#  ('bricks,', 0),
#  ('continued', 0),
#  ('"thank\'ee,"', 0),
#  ('prime', 0),
#  ("pharaoh's", 0),
#  ('doors,', 0),
#  ('child;', 0),
#  ('ledgers,', 0),
#  ('intimation', 0),
#  ('predicted', 0),
#  ('giant,', 0),
#  ('wailings', 0),
#  ('waste,', 0),
#  ('mossy,', 0),
#  ('higher,', 0),
#  ('avarice.', 0),
#  ('exchanging', 0),
#  ('hideous,', 0),
#  ('course,"', 0),
#  ('oranges,', 0),
#  ('approached', 0),
#  ('teach', 0),
#  ('sheets', 0),
#  ('wiser,', 0),
#  ("prophet's", 0),
#  ('martha!"', 0),
#  ('"nothing!"', 0),
#  ('channels,', 0),
#  ('grasping,', 0),
#  ('spoke.', 0),
#  ('impatiently.', 0),
#  ('speaking', 0),
#  ('rejoined.', 0),
#  ('ebenezer."', 0),
#  ('indeed."', 0),
#  ('ages', 0),
#  ('bedight', 0),
#  ('baba!', 0),
#  ('recognition', 0),
#  ('years;', 0),
#  ('term.', 0),
#  ('"she', 0),
#  ('apparel,', 0),
#  ('uncurtained', 0),
#  ('street,', 0),
#  ('die?"', 0),
#  ('breezy', 0),
#  ('time!"', 0),
#  ('stages', 0),
#  ('more!', 0),
#  ("vision's", 0),
#  ('holidays.', 0),
#  ('end,', 0),
#  ('grating', 0),
#  ('sunlight;', 0),
#  ('"long', 0),
#  ('bass', 0),
#  ('there!"', 0),
#  ('eyes.', 0),
#  ('glow!', 0),
#  ('dismal?', 0),
#  ('poverty,', 0),
#  ('messenger', 0),
#  ('extensive.', 0),
#  ('book', 0),
#  ('hopes,', 0),
#  ('gruel.', 0),
#  ('platter!', 0),
#  ('way:', 0),
#  ('garment.', 0),
#  ('tail;', 0),
#  ('owner,', 0),
#  ("i've", 0),
#  ('goose.', 0),
#  ('finish', 0),
#  ('numbers', 0),
#  ('hob,', 0),
#  ('laughed;', 0),
#  ('sucking-pigs,', 0),
#  ('joints', 0),
#  ('race,"', 0),
#  ('steeped', 0),
#  ('disposed', 0),
#  ('again!"', 0),
#  ('mayor,', 0),
#  ('"both', 0),
#  ('bull,', 0),
#  ('dispelled', 0),
#  ('weather:', 0),
#  ('clash,', 0),
#  ('"never,"', 0),
#  ('undertaker,', 0),
#  ('itself,"', 0),
#  ('glimpses!', 0),
#  ('lips;', 0),
#  ('capital', 0),
#  ('specks', 0),
#  ('fear:', 0),
#  ('echoes', 0),
#  ('offices', 0),
#  ('ye', 0),
#  ('pursued.', 0),
#  ('six--barred', 0),
#  ('sprinkled', 0),
#  ('possible,"', 0),
#  ("men's", 0),
#  ('fast,', 0),
#  ('anywhere.', 0),
#  ('pities', 0),
#  ('sang', 0),
#  ('precepts.', 0),
#  ('avoid', 0),
#  ('glow,', 0),
#  ('size,', 0),
#  ('stop!', 0),
#  ('sheba,', 0),
#  ('addressing', 0),
#  ('sprinkle', 0),
#  ('coaches', 0),
#  ('law', 0),
#  ('five-and-sixpence', 0),
#  ('gladly,', 0),
#  ('black.', 0),
#  ('cracked;', 0),
#  ('erased.', 0),
#  ('lives.', 0),
#  ('shyly,', 0),
#  ('faint', 0),
#  ('own;', 0),
#  ('pushing,', 0),
#  ('savour', 0),
#  ('task,', 0),
#  ('door-step.', 0),
#  ('manner.', 0),
#  ('town', 0),
#  ('children!', 0),
#  ('bilious.', 0),
#  ('brandy,', 0),
#  ('desirable', 0),
#  ('anonymous?"', 0),
#  ('briskly', 0),
#  ("milliner's,", 0),
#  ('groups,', 0),
#  ('rattled', 0),
#  ('care!', 0),
#  ('sort,', 0),
#  ('subjects,', 0),
#  ('charwoman', 0),
#  ('good?"', 0),
#  ('abels,', 0),
#  ('myself,"', 0),
#  ('flushed', 0),
#  ('heaven!"', 0),
#  ('pride,', 0),
#  ('stagnant-blooded', 0),
#  ('trouble.', 0),
#  ('checked', 0),
#  ('strangers.', 0),
#  ('charcoal', 0),
#  ('de', 0),
#  ('liable', 0),
#  ("father's", 0),
#  ('outset', 0),
#  ('iron,', 0),
#  ('demons,', 0),
#  ('jacob!"', 0),
#  ('true;', 0),
#  ('heaving', 0),
#  ('received.', 0),
#  ('courage', 0),
#  ('charged', 0),
#  ('narrow;', 0),
#  ('suddenly', 0),
#  ('kept', 0),
#  ('gloomy', 0),
#  ('quickening', 0),
#  ('milkman.', 0),
#  ('steeples', 0),
#  ('wink', 0),
#  ('pretty.', 0),
#  ('nephew!"', 0),
#  ('him)', 0),
#  ('nothing:', 0),
#  ('freely,', 0),
#  ('gets', 0),
#  ('laths', 0),
#  ('took,', 0),
#  ('base,', 0),
#  ('bob!', 0),
#  ('whitechapel,', 0),
#  ('also,', 0),
#  ('vast.', 0),
#  ('hid', 0),
#  ('wings', 0),
#  ('spared."', 0),
#  ('land,', 0),
#  ('hurrying', 0),
#  ('wasn\'t,"', 0),
#  ('stair', 0),
#  ('clear.', 0),
#  ('twisting', 0),
#  ('cannon-ball,', 0),
#  ('issue', 0),
#  ("grocers'", 0),
#  ('water-spout', 0),
#  ('thing."', 0),
#  ('detained', 0),
#  ('solemnised', 0),
#  ('"often."', 0),
#  ('spacious', 0),
#  ('breast,', 0),
#  ('bunches', 0),
#  ('told,', 0),
#  ('consolation', 0),
#  ('sunniest', 0),
#  ('was."', 0),
#  ('afford', 0),
#  ('truly', 0),
#  ('rising', 0),
#  ('blotch', 0),
#  ('anxiously', 0),
#  ('shadowing', 0),
#  ('half-thawed', 0),
#  ('eh?"', 0),
#  ('lustrous', 0),
#  ("home's", 0),
#  ('thither', 0),
#  ('up:', 0),
#  ('servant,', 0),
#  ('proceedings', 0),
#  ('field', 0),
#  ('stiffened', 0),
#  ('ones', 0),
#  ('"yes,"', 0),
#  ('pursued,', 0),
#  ('apple-sauce;', 0),
#  ('factious', 0),
#  ('myself,', 0),
#  ('exceedingly', 0),
#  ('marley!', 0),
#  ('thermometer', 0),
#  ('gone."', 0),
#  ('hopeful', 0),
#  ('regularly', 0),
#  ('sheds', 0),
#  ('bob!"', 0),
#  ('mourning-dress:', 0),
#  ('conversed', 0),
#  ('am!"', 0),
#  ('exulted!', 0),
#  ('swell', 0),
#  ('naked', 0),
#  ('penny,', 0),
#  ('shortest', 0),
#  ('touch,', 0),
#  ('skirts,', 0),
#  ('dealt', 0),
#  ("blindman's-buff.", 0),
#  ('"\'and', 0),
#  ('frowned,', 0),
#  ('pigtail', 0),
#  ('dinner,"', 0),
#  ('jug,', 0),
#  ('brood,', 0),
#  ('spoil,', 0),
#  ('bear?"', 0),
#  ('twenty-fifth', 0),
#  ('proffering', 0),
#  ('lips', 0),
#  ('attractive', 0),
#  ('sister.', 0),
#  ('tread.', 0),
#  ('gate.', 0),
#  ('times.', 0),
#  ('come,"', 0),
#  ('"lord', 0),
#  ('inspection,', 0),
#  ('evenings,', 0),
#  ('"man,"', 0),
#  ('supposed.', 0),
#  ('curls', 0),
#  ('trunk', 0),
#  ('threshold', 0),
#  ('claim', 0),
#  ('referring', 0),
#  ('due', 0),
#  ('credulity,', 0),
#  ('proclaimed', 0),
#  ('arose', 0),
#  ('wherein', 0),
#  ('beings', 0),
#  ('barred', 0),
#  ('dancers', 0),
#  ('warn', 0),
#  ('candles', 0),
#  ('mouths,', 0),
#  ('offices.', 0),
#  ('tripped', 0),
#  ('pulpy,', 0),
#  ('hood', 0),
#  ('lamplighter,', 0),
#  ('possible;', 0),
#  ('repleted', 0),
#  ('grows', 0),
#  ('die', 0),
#  ('even-handed,', 0),
#  ('approach.', 0),
#  ('rats', 0),
#  ('bide', 0),
#  ('resort,', 0),
#  ("misery's", 0),
#  ('extravagant', 0),
#  ('neither', 0),
#  ('kitchens,', 0),
#  ('unwept,', 0),
#  ...]

# %% [markdown]
# ## Generators/Yield

# %%
import random
lst = [random.randint(0, 10) for _ in range(20)]
lst
# Out:
# [9, 1, 10, 2, 0, 6, 5, 8, 5, 10, 6, 8, 9, 2, 6, 4, 7, 9, 9, 5]

# %%
lst = []
for _ in range(20):  # count to 20
    lst.append(random.randint(0, 10))  # add random int between 0 and 10
lst
# Out:
# [3, 10, 8, 6, 6, 4, 10, 9, 7, 2, 1, 3, 1, 0, 6, 2, 0, 5, 4, 3]

# %%
# square every element in lst










# SOLUTION
new_list = [x**2 for x in lst]

# %%
#
